# %%
import pandas as pd

data = pd.read_csv("review_final_38.csv", encoding="cp949")
data = data.drop("Unnamed: 0", axis=1)

# %%
data.head(5)
# Out:
#    bad  good                                              reple  score movie  \
# 0  126  1427               BEST강동원 너 나오면 꼭 보러가는거 알지????최소 다섯번       10  검사외전
# 1   48  1065  BEST강동원, 황정민, 이성민. 티켓파워는 걱정없고 영화만 잘 빠지면 백퍼 흥행한다       10  검사외전
# 2   46   867                          BEST황정민 이번작품도 기대하겠습니다!!       10  검사외전
# 3   43   722                          BEST황정민 이번 영화 다들 장난 아닌듯       10  검사외전
# 4   53   689                     BEST동원오빠 훌륭한연기 기대할게요! 응원합니다!       10  검사외전
#
#    y
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
import re
data["reple"] = [i.replace("BEST","") for i in data["reple"]]

# %%
positive = data[data["y"]==1]
negative = data[data["y"]==0]

# %%
from konlpy.tag import Twitter
twitter = Twitter()

# %%
def token_word(line):    
    hangul = re.compile('[^ㄱ-ㅣ가-힣]+') # 한글과 띄어쓰기를 제외한 모든 글자
    result = hangul.sub(' ', line) # 한글과 띄어쓰기를 제외한 모든 부분을 제거
    return result

# %%
reple = [k for k in positive["reple"]]
reple = [token_word(k) for k in reple]
positive["reple"] = reple

reple = [k for k in negative["reple"]]
reple = [token_word(k) for k in reple]
negative["reple"] = reple
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
tagger_p = [twitter.pos(line) for line in positive['reple']]
tagger_n = [twitter.pos(line) for line in negative['reple']]

# %%
tagger_p
# Out:
# [[('강동원', 'Noun'),
#   ('너', 'Noun'),
#   ('나오면', 'Verb'),
#   ('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('가', 'PreEomi'),
#   ('는', 'PreEomi'),
#   ('거', 'Eomi'),
#   ('알', 'Noun'),
#   ('지', 'Josa'),
#   ('최소', 'Noun'),
#   ('다섯', 'Determiner'),
#   ('번', 'Noun')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('이성민', 'Noun'),
#   ('티켓파워', 'Noun'),
#   ('는', 'Josa'),
#   ('걱정', 'Noun'),
#   ('없고', 'Adjective'),
#   ('영화', 'Noun'),
#   ('만', 'Josa'),
#   ('잘', 'Verb'),
#   ('빠지', 'Verb'),
#   ('면', 'Eomi'),
#   ('백퍼', 'Noun'),
#   ('흥행', 'Noun'),
#   ('한', 'Verb'),
#   ('다', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('이번', 'Noun'),
#   ('작품', 'Noun'),
#   ('도', 'Josa'),
#   ('기대하겠', 'Adjective'),
#   ('습니다', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('이번', 'Noun'),
#   ('영화', 'Noun'),
#   ('다', 'Adverb'),
#   ('들', 'Verb'),
#   ('장난', 'Noun'),
#   ('아닌', 'Adjective'),
#   ('듯', 'Eomi')],
#  [('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('훌륭한', 'Adjective'),
#   ('연기', 'Noun'),
#   ('기대할', 'Adjective'),
#   ('게요', 'Eomi'),
#   ('응원', 'Noun'),
#   ('합', 'Verb'),
#   ('니다', 'Eomi')],
#  [('와아아', 'Exclamation'),
#   ('아', 'Exclamation'),
#   ('강동원', 'Noun'),
#   ('나와라', 'Noun'),
#   ('아아', 'Exclamation'),
#   ('아아', 'Exclamation')],
#  [('강동원', 'Noun'), ('기대할', 'Adjective'), ('게요', 'Eomi')],
#  [('여기', 'Noun'),
#   ('강동원', 'Noun'),
#   ('나오', 'Verb'),
#   ('나요', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('다', 'Eomi'),
#   ('ㅜㅜ', 'KoreanParticle')],
#  [('정민', 'Noun'),
#   ('이형', 'Noun'),
#   ('이번', 'Noun'),
#   ('에도', 'Josa'),
#   ('기대', 'Noun')],
#  [('황정민', 'Noun'), ('강동원', 'Noun'), ('걍', 'Adverb'), ('지릴듯', 'Noun')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('후', 'Noun'),
#   ('덜덜', 'Noun'),
#   ('짱', 'Noun'),
#   ('재미있', 'Adjective'),
#   ('을', 'Eomi'),
#   ('듯', 'Noun')],
#  [('강동원', 'Noun'),
#   ('꼭', 'Noun'),
#   ('나와라', 'Noun'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('조합', 'Noun'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('올', 'NounPrefix'),
#   ('해안', 'Noun'),
#   ('에', 'Josa'),
#   ('꼭', 'Noun'),
#   ('개봉', 'Noun'),
#   ('했', 'Verb'),
#   ('으면', 'Eomi'),
#   ('ㅠㅠ', 'KoreanParticle'),
#   ('강동원', 'Noun'),
#   ('남우', 'Noun'),
#   ('주연', 'Noun'),
#   ('상', 'Suffix'),
#   ('후보', 'Noun'),
#   ('가자', 'Verb')],
#  [('강', 'Noun'), ('동', 'Noun'), ('원', 'Noun'), ('사랑해', 'Verb'), ('요', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('쉬', 'Noun'),
#   ('기는', 'Verb'),
#   ('하는', 'Verb'),
#   ('거', 'Eomi'),
#   ('임', 'Noun'),
#   ('ㅠ', 'KoreanParticle'),
#   ('작품', 'Noun'),
#   ('진짜', 'Noun'),
#   ('많이', 'Adverb'),
#   ('한', 'Verb'),
#   ('다', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('꼭', 'Noun'),
#   ('나와라', 'Noun'),
#   ('라', 'Josa'),
#   ('아아', 'Noun'),
#   ('아', 'Josa')],
#  [('강동원', 'Noun'),
#   ('이', 'Josa'),
#   ('나오면', 'Verb'),
#   ('그냥', 'Noun'),
#   ('닥치고', 'Noun'),
#   ('봐', 'Noun'),
#   ('야한', 'Adjective'),
#   ('다', 'Eomi')],
#  [('국제', 'Noun'),
#   ('시장', 'Noun'),
#   ('황정민', 'Noun'),
#   ('쩔던', 'Verb'),
#   ('데', 'Eomi'),
#   ('이번', 'Noun'),
#   ('작도', 'Noun'),
#   ('대박', 'Noun'),
#   ('나길', 'Verb')],
#  [('그냥', 'Noun'),
#   ('캐스팅', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('대박', 'Noun'),
#   ('날', 'Verb'),
#   ('것', 'PreEomi'),
#   ('같은', 'Adjective'),
#   ('이', 'Determiner'),
#   ('예감', 'Noun'),
#   ('강동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('쨔응', 'Noun')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이성민', 'Noun'),
#   ('을', 'Josa'),
#   ('한번', 'Noun'),
#   ('에', 'Josa'),
#   ('볼', 'Noun'),
#   ('수가', 'Noun'),
#   ('있다', 'Adjective'),
#   ('니', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이라니', 'Josa'),
#   ('게다가', 'Noun'),
#   ('이성민', 'Noun'),
#   ('과', 'Josa'),
#   ('박성웅', 'Noun'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('의', 'Josa'),
#   ('케미', 'Noun'),
#   ('와', 'Josa'),
#   ('연기', 'Noun'),
#   ('정말', 'Noun'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi')],
#  [('강동원', 'Noun'), ('짝', 'Noun'), ('강동원', 'Noun'), ('짝', 'Noun')],
#  [('와', 'Noun'),
#   ('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('의', 'Josa'),
#   ('만남', 'Noun'),
#   ('말', 'Noun'),
#   ('다했', 'Verb'),
#   ('네', 'Eomi'),
#   ('뭐', 'Noun')],
#  [('전과', 'Noun'),
#   ('범', 'Noun'),
#   ('꽃미남', 'Noun'),
#   ('사기꾼', 'Noun'),
#   ('읽', 'Verb'),
#   ('자마자', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('이라는', 'Josa'),
#   ('걸', 'Noun'),
#   ('알', 'Verb'),
#   ('았', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('요즘', 'Noun'),
#   ('가장', 'Noun'),
#   ('핫', 'Noun'),
#   ('한', 'Josa'),
#   ('배우', 'Noun'),
#   ('황정민', 'Noun'),
#   ('에다가', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이라니', 'Josa'),
#   ('초', 'Noun'),
#   ('대박', 'Noun'),
#   ('캐스팅', 'Noun'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi')],
#  [('믿음', 'Noun'),
#   ('가는', 'Verb'),
#   ('멋진', 'Adjective'),
#   ('감독', 'Noun'),
#   ('이일형', 'Noun'),
#   ('화이팅', 'Noun'),
#   ('검사', 'Noun'),
#   ('외전', 'Noun'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('아', 'Exclamation'),
#   ('대박', 'Noun'),
#   ('참치', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('열', 'Noun'),
#   ('일하신', 'Verb'),
#   ('다', 'Eomi'),
#   ('ㅠㅠ', 'KoreanParticle'),
#   ('만세', 'Noun')],
#  [('말', 'Noun'),
#   ('이', 'Josa'),
#   ('필요없', 'Adjective'),
#   ('는', 'Eomi'),
#   ('조합', 'Noun'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('박성웅', 'Noun'),
#   ('무조건', 'Noun'),
#   ('위', 'Noun')],
#  [('황정민', 'Noun'),
#   ('믿고', 'Verb'),
#   ('기대', 'Noun'),
#   ('가득', 'Noun'),
#   ('차서', 'Noun'),
#   ('보러', 'Verb'),
#   ('갑', 'Verb'),
#   ('니다', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이', 'Suffix'),
#   ('면', 'Josa'),
#   ('할', 'Verb'),
#   ('말', 'Noun'),
#   ('다', 'Adverb'),
#   ('했', 'Verb'),
#   ('다', 'Eomi')],
#  [('하아', 'Exclamation'),
#   ('황정민', 'Noun'),
#   ('에', 'Josa'),
#   ('강동원', 'Noun'),
#   ('까지', 'Noun'),
#   ('나', 'Noun'),
#   ('앓아', 'Verb'),
#   ('누워', 'Verb'),
#   ('요', 'Eomi'),
#   ('감독', 'Noun'),
#   ('님', 'Suffix')],
#  [('동원', 'Noun'),
#   ('오빠', 'Noun'),
#   ('당신', 'Noun'),
#   ('이기', 'Noun'),
#   ('에', 'Josa'),
#   ('봅', 'Verb'),
#   ('니다', 'Eomi')],
#  [('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('나오면', 'Verb'),
#   ('무조건', 'Noun'),
#   ('간', 'Suffix'),
#   ('다', 'Josa')],
#  [('배우', 'Noun'),
#   ('라인업', 'Noun'),
#   ('은', 'Josa'),
#   ('최강', 'Noun'),
#   ('임', 'Noun'),
#   ('영화', 'Noun'),
#   ('만', 'Josa'),
#   ('잘', 'VerbPrefix'),
#   ('빠지', 'Verb'),
#   ('면', 'Eomi'),
#   ('문제', 'Noun'),
#   ('없이', 'Adverb'),
#   ('흥행', 'Noun'),
#   ('한', 'Verb'),
#   ('다', 'Eomi')],
#  [('진짜', 'Noun'),
#   ('이건', 'Noun'),
#   ('절', 'Noun'),
#   ('대안', 'Noun'),
#   ('볼', 'Verb'),
#   ('수', 'PreEomi'),
#   ('가', 'Eomi'),
#   ('없다', 'Adjective'),
#   ('필수', 'Noun'),
#   ('다', 'Josa'),
#   ('무', 'Noun'),
#   ('조', 'Noun'),
#   ('건', 'Noun')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('다', 'Adverb'),
#   ('들', 'Verb'),
#   ('기대하자', 'Adjective')],
#  [('강동원', 'Noun'),
#   ('촬영', 'Noun'),
#   ('겹', 'Noun'),
#   ('쳐', 'Verb'),
#   ('서', 'Eomi'),
#   ('안', 'VerbPrefix'),
#   ('할', 'Verb'),
#   ('까', 'Eomi'),
#   ('걱정했', 'Verb'),
#   ('는데', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('최고', 'Noun'),
#   ('시', 'Noun'),
#   ('다', 'Josa')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이라니', 'Josa'),
#   ('신선한', 'Adjective'),
#   ('조합', 'Noun'),
#   ('정말', 'Noun'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('나오면', 'Verb'),
#   ('꼭', 'Noun'),
#   ('보는', 'Verb'),
#   ('인', 'Noun'),
#   ('ㅋㅋ', 'KoreanParticle')],
#  [('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('배우', 'Noun'),
#   ('이성민', 'Noun'),
#   ('배우', 'Noun'),
#   ('님', 'Suffix'),
#   ('악역', 'Noun'),
#   ('연기', 'Noun'),
#   ('정말', 'Noun'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi'),
#   ('손님', 'Noun'),
#   ('에서도', 'Josa'),
#   ('악역', 'Noun'),
#   ('연기', 'Noun'),
#   ('넘', 'Verb'),
#   ('좋', 'Adjective'),
#   ('았', 'PreEomi'),
#   ('는데', 'Eomi'),
#   ('이번', 'Noun'),
#   ('작품', 'Noun'),
#   ('에서도', 'Josa'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('어떤', 'Adjective'),
#   ('조합', 'Noun'),
#   ('을', 'Josa'),
#   ('보여', 'Verb'),
#   ('줄', 'PreEomi'),
#   ('지', 'Eomi'),
#   ('기대할', 'Adjective'),
#   ('게요', 'Eomi')],
#  [('보조', 'Noun'),
#   ('출연', 'Noun'),
#   ('갔', 'Verb'),
#   ('다가', 'Eomi'),
#   ('황정민', 'Noun'),
#   ('연기', 'Noun'),
#   ('보고', 'Noun'),
#   ('소름', 'Noun'),
#   ('돋', 'Adjective'),
#   ('음', 'Eomi'),
#   ('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('꼭', 'Noun'),
#   ('볼', 'Verb'),
#   ('거', 'Eomi'),
#   ('임', 'Noun')],
#  [('참치', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('나오니', 'Verb'),
#   ('까', 'Eomi'),
#   ('보러', 'Verb'),
#   ('감', 'Noun'),
#   ('꺄', 'Noun')],
#  [('배우', 'Noun'),
#   ('만', 'Josa'),
#   ('봐', 'Noun'),
#   ('도', 'Josa'),
#   ('기대되', 'Verb'),
#   ('고', 'Eomi'),
#   ('스토리', 'Noun'),
#   ('도', 'Josa'),
#   ('재밌', 'Adjective'),
#   ('을', 'Eomi'),
#   ('것', 'Noun'),
#   ('같다', 'Adjective')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('연기', 'Noun'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('영화', 'Noun'),
#   ('대박', 'Noun'),
#   ('나길', 'Verb')],
#  [('하', 'PreEomi'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('ㅜㅜㅜ', 'KoreanParticle'),
#   ('생각', 'Noun'),
#   ('만', 'Suffix'),
#   ('해도', 'Josa'),
#   ('설렘', 'Adjective'),
#   ('박성웅', 'Noun'),
#   ('까지', 'Josa'),
#   ('강동원', 'Noun'),
#   ('은', 'Josa'),
#   ('진심', 'Noun'),
#   ('리즈', 'Noun'),
#   ('때', 'Noun'),
#   ('필름', 'Noun'),
#   ('으로', 'Josa'),
#   ('많이', 'Adverb'),
#   ('남겨', 'Verb'),
#   ('놔', 'Verb'),
#   ('야함', 'Adjective'),
#   ('ㅎㅎㅎㅎ', 'KoreanParticle'),
#   ('문화', 'Noun'),
#   ('재임', 'Noun')],
#  [('검은', 'Adjective'),
#   ('사제', 'Noun'),
#   ('들', 'Suffix'),
#   ('이어서', 'Adverb'),
#   ('쭉쭉', 'Noun'),
#   ('대박', 'Noun'),
#   ('나자', 'Verb'),
#   ('강동원', 'Noun'),
#   ('화이팅', 'Noun')],
#  [('답', 'Noun'),
#   ('은', 'Josa'),
#   ('간단해', 'Adjective'),
#   ('강동원', 'Noun'),
#   ('이', 'Suffix'),
#   ('니깐', 'Josa')],
#  [('갓', 'Noun'),
#   ('동원', 'Noun'),
#   ('ㅠㅠㅠ', 'KoreanParticle'),
#   ('나', 'Noun'),
#   ('랑', 'Josa'),
#   ('결혼', 'Noun'),
#   ('해줘', 'Verb'),
#   ('요', 'Eomi'),
#   ('젲발', 'Noun')],
#  [('예상', 'Noun'),
#   ('리뷰', 'Noun'),
#   ('극', 'NounPrefix'),
#   ('전개', 'Noun'),
#   ('가', 'Josa'),
#   ('치밀', 'Noun'),
#   ('한', 'Determiner'),
#   ('데', 'Noun'),
#   ('강원', 'Noun'),
#   ('동이', 'Noun'),
#   ('잘생겼', 'Adjective'),
#   ('고', 'Eomi'),
#   ('황정민', 'Noun'),
#   ('연기', 'Noun'),
#   ('는', 'Josa'),
#   ('더', 'Noun'),
#   ('이상', 'Noun'),
#   ('말', 'Noun'),
#   ('이', 'Josa'),
#   ('필', 'Verb'),
#   ('오', 'Eomi'),
#   ('없는', 'Adjective'),
#   ('데', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('이', 'Josa'),
#   ('잘', 'Verb'),
#   ('생겼', 'Verb'),
#   ('으며', 'Eomi'),
#   ('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('이성민', 'Noun'),
#   ('은', 'Josa'),
#   ('영화', 'Noun'),
#   ('에서도', 'Josa'),
#   ('존재', 'Noun'),
#   ('감', 'Noun'),
#   ('쩌는데', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이', 'Josa'),
#   ('잘생겼', 'Adjective'),
#   ('다', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('껄렁', 'Adverb'),
#   ('거리', 'Noun'),
#   ('는', 'Josa'),
#   ('이미지', 'Noun'),
#   ('도', 'Josa'),
#   ('넘', 'Verb'),
#   ('넘', 'Verb'),
#   ('사랑스러워', 'Adjective'),
#   ('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('갑', 'Verb'),
#   ('니다', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('이', 'Josa'),
#   ('검사', 'Noun'),
#   ('나', 'Josa'),
#   ('형사', 'Noun'),
#   ('로', 'Josa'),
#   ('나오는', 'Verb'),
#   ('것', 'PreEomi'),
#   ('만으로도', 'Eomi'),
#   ('점', 'Noun'),
#   ('만점', 'Noun'),
#   ('인데', 'Josa'),
#   ('거기', 'Noun'),
#   ('다', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이라니', 'Josa'),
#   ('완전', 'Noun'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('ㅠㅠ', 'KoreanParticle'),
#   ('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('황정민', 'Noun'),
#   ('무조건', 'Noun'),
#   ('보는', 'Verb'),
#   ('강동원', 'Noun')],
#  [('검은', 'Adjective'),
#   ('사제', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('재미있게', 'Adjective'),
#   ('봤', 'Verb'),
#   ('는데', 'Eomi'),
#   ('검사', 'Noun'),
#   ('외전', 'Noun'),
#   ('은', 'Josa'),
#   ('얼마나', 'Noun'),
#   ('재미있', 'Adjective'),
#   ('을까', 'Eomi'),
#   ('기대되', 'Verb'),
#   ('고', 'Eomi'),
#   ('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('가', 'Josa'),
#   ('연달', 'Noun'),
#   ('아', 'Josa'),
#   ('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('나와', 'Verb'),
#   ('서', 'Eomi'),
#   ('되게', 'Adverb'),
#   ('흐믓하', 'Noun'),
#   ('다', 'Josa'),
#   ('ㅠㅠ', 'KoreanParticle')],
#  [('강동원', 'Noun'),
#   ('에', 'Josa'),
#   ('황정민', 'Noun'),
#   ('이라니', 'Josa'),
#   ('둘', 'Noun'),
#   ('의', 'Josa'),
#   ('조합', 'Noun'),
#   ('정말', 'Noun'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('솔직히', 'Adjective'),
#   ('기대', 'Verb'),
#   ('치', 'PreEomi'),
#   ('보단', 'Eomi'),
#   ('못', 'Noun'),
#   ('한', 'Josa'),
#   ('영화', 'Noun'),
#   ('그냥', 'Noun'),
#   ('좋', 'Adjective'),
#   ('은', 'Eomi'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('모아', 'Verb'),
#   ('놓', 'PreEomi'),
#   ('은', 'Eomi'),
#   ('상업', 'Noun'),
#   ('식', 'Noun'),
#   ('영화', 'Noun'),
#   ('그래도', 'Adverb'),
#   ('여자', 'Noun'),
#   ('들', 'Suffix'),
#   ('은', 'Josa'),
#   ('강동원', 'Noun'),
#   ('땜', 'Noun'),
#   ('에', 'Josa'),
#   ('너무', 'Noun'),
#   ('좋아하더', 'Adjective'),
#   ('라', 'Eomi')],
#  [('벌써', 'Noun'),
#   ('부터', 'Josa'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('믿고', 'Verb'),
#   ('봅', 'Verb'),
#   ('니다', 'Eomi'),
#   ('이영화', 'Noun')],
#  [('황정민', 'Noun'),
#   ('아저씨', 'Noun'),
#   ('이', 'Determiner'),
#   ('번영', 'Noun'),
#   ('화', 'Suffix'),
#   ('도', 'Josa'),
#   ('완전', 'Noun'),
#   ('기대할', 'Adjective'),
#   ('게요', 'Eomi'),
#   ('항상', 'Noun'),
#   ('화이팅', 'Noun'),
#   ('하세', 'Verb'),
#   ('요', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이', 'Suffix'),
#   ('면', 'Josa'),
#   ('말', 'Noun'),
#   ('다했', 'Verb'),
#   ('지', 'Eomi')],
#  [('스토리', 'Noun'),
#   ('만', 'Josa'),
#   ('괜찮', 'Adjective'),
#   ('다면', 'Eomi'),
#   ('천만', 'Noun'),
#   ('관객', 'Noun'),
#   ('거뜬히', 'Adverb'),
#   ('넘긴', 'Verb'),
#   ('다', 'Eomi'),
#   ('진심', 'Noun')],
#  [('시사회', 'Noun'),
#   ('다녀왔', 'Verb'),
#   ('는데', 'Eomi'),
#   ('걍', 'Adverb'),
#   ('꿀잼', 'Noun'),
#   ('자글자글', 'Adverb'),
#   ('쓰', 'Verb'),
#   ('고', 'PreEomi'),
#   ('싶', 'PreEomi'),
#   ('은데', 'Eomi'),
#   ('스포', 'Noun'),
#   ('될', 'Verb'),
#   ('까봐', 'Eomi'),
#   ('자제', 'Noun'),
#   ('함', 'Noun'),
#   ('포인트', 'Noun'),
#   ('는', 'Josa'),
#   ('박성웅', 'Noun'),
#   ('이', 'Josa'),
#   ('졸귀', 'Noun'),
#   ('탱', 'Adverb'),
#   ('임', 'Noun'),
#   ('ㅎㅎㅎ', 'KoreanParticle'),
#   ('걍', 'Adverb'),
#   ('돈', 'Noun'),
#   ('주고', 'Verb'),
#   ('봐', 'Noun'),
#   ('도', 'Josa'),
#   ('안아', 'Verb'),
#   ('까', 'Eomi'),
#   ('움', 'Noun'),
#   ('ㅎㅎ', 'KoreanParticle')],
#  [('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('눈부신', 'Adjective'),
#   ('갓', 'Noun'),
#   ('동원', 'Noun'),
#   ('님', 'Suffix'),
#   ('께서', 'Josa'),
#   ('나오신', 'Verb'),
#   ('다면', 'Eomi'),
#   ('한번', 'Noun'),
#   ('보', 'Verb'),
#   ('는걸', 'Eomi'),
#   ('론', 'Noun'),
#   ('부족하다', 'Adjective')],
#  [('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('갈', 'Verb'),
#   ('게', 'Eomi'),
#   ('용', 'Noun')],
#  [('강동원', 'Noun'),
#   ('의', 'Josa'),
#   ('연기력', 'Noun'),
#   ('도', 'Josa'),
#   ('기대되', 'Verb'),
#   ('고', 'Eomi'),
#   ('황정민', 'Noun'),
#   ('의', 'Josa'),
#   ('연기력', 'Noun'),
#   ('도', 'Josa'),
#   ('엄청', 'Adverb'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi')],
#  [('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('황정민', 'Noun'),
#   ('인간미', 'Noun'),
#   ('넘치는', 'Verb'),
#   ('배우', 'Noun'),
#   ('사랑합', 'Verb'),
#   ('니다', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('사랑해', 'Verb'),
#   ('검사', 'Noun'),
#   ('외전', 'Noun'),
#   ('이라', 'Verb'),
#   ('길래', 'Eomi'),
#   ('검은', 'Adjective'),
#   ('사제', 'Noun'),
#   ('들', 'Suffix'),
#   ('외전', 'Noun'),
#   ('하악하악', 'Noun'),
#   ('거리', 'Noun'),
#   ('고', 'Josa'),
#   ('있었', 'Adjective'),
#   ('는데', 'Eomi'),
#   ('새로운', 'Adjective'),
#   ('영화', 'Noun'),
#   ('였', 'Verb'),
#   ('네', 'Eomi'),
#   ('ㅎㅎ', 'KoreanParticle'),
#   ('뎨둉해', 'Noun'),
#   ('여', 'Josa'),
#   ('강동원', 'Noun'),
#   ('님', 'Suffix'),
#   ('나오는', 'Verb'),
#   ('영화', 'Noun'),
#   ('면', 'Josa'),
#   ('번은', 'Noun'),
#   ('더', 'Noun'),
#   ('보겠', 'Verb'),
#   ('습니다', 'Eomi'),
#   ('검은', 'Adjective'),
#   ('사제', 'Noun'),
#   ('들', 'Suffix'),
#   ('아직', 'Noun'),
#   ('도', 'Josa'),
#   ('돌려', 'Verb'),
#   ('보고', 'Verb'),
#   ('있', 'PreEomi'),
#   ('다고', 'Eomi'),
#   ('젠장', 'Noun')],
#  [('소', 'Noun'),
#   ('처럼', 'Josa'),
#   ('일한', 'Verb'),
#   ('다는', 'Eomi'),
#   ('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('화이팅', 'Noun')],
#  [('구', 'Noun'), ('우우', 'Adverb'), ('우', 'Adverb'), ('웃', 'Noun')],
#  [('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('항상', 'Noun'),
#   ('응원', 'Noun'),
#   ('해', 'Josa'),
#   ('요', 'Noun'),
#   ('예뻐', 'Adjective'),
#   ('요', 'Eomi'),
#   ('웃음', 'Noun'),
#   ('이', 'Josa'),
#   ('기대합', 'Adjective'),
#   ('니다', 'Eomi'),
#   ('축복', 'Noun')],
#  [('재밌', 'Adjective'),
#   ('을', 'PreEomi'),
#   ('듯', 'Eomi'),
#   ('개봉', 'Noun'),
#   ('되', 'Verb'),
#   ('자마자', 'Eomi'),
#   ('바로', 'Noun'),
#   ('보러', 'Verb'),
#   ('가', 'PreEomi'),
#   ('야', 'Eomi'),
#   ('짛', 'Noun'),
#   ('ㅎㅎㅎ', 'KoreanParticle')],
#  [('요즘', 'Noun'),
#   ('유아인', 'Noun'),
#   ('강동원', 'Noun'),
#   ('두', 'Determiner'),
#   ('배우', 'Noun'),
#   ('가', 'Josa'),
#   ('제일', 'Noun'),
#   ('열심히', 'Adverb'),
#   ('하는', 'Verb'),
#   ('것', 'PreEomi'),
#   ('같아', 'Adjective'),
#   ('요', 'Eomi'),
#   ('벌써', 'Noun'),
#   ('몇', 'NounPrefix'),
#   ('작품', 'Noun'),
#   ('을', 'Josa'),
#   ('ㄷㄷ', 'KoreanParticle')],
#  [('배우', 'Noun'),
#   ('부터', 'Josa'),
#   ('천만', 'Noun'),
#   ('끝', 'Noun'),
#   ('이네', 'Josa'),
#   ('요', 'Noun')],
#  [('소율', 'Noun'),
#   ('누나', 'Noun'),
#   ('완소', 'Noun'),
#   ('화이팅', 'Noun'),
#   ('요', 'Josa')],
#  [('참치', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('빨리', 'Adverb'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('ㅠㅜ', 'KoreanParticle')],
#  [('너무', 'Noun'),
#   ('기대하면', 'Adjective'),
#   ('안되는', 'Verb'),
#   ('데', 'Eomi'),
#   ('기대', 'Noun'),
#   ('가', 'Josa'),
#   ('되는', 'Verb'),
#   ('건', 'Eomi'),
#   ('어쩔', 'Verb'),
#   ('수', 'Noun'),
#   ('없', 'Adjective'),
#   ('나', 'PreEomi'),
#   ('보다', 'Eomi'),
#   ('ㅋㅋㅋ', 'KoreanParticle'),
#   ('빨리', 'Adverb'),
#   ('개봉일', 'Noun'),
#   ('이', 'Josa'),
#   ('됐', 'Verb'),
#   ('으면', 'Eomi'),
#   ('ㅜㅜㅠ', 'KoreanParticle')],
#  [('아', 'Exclamation'),
#   ('씨', 'Noun'),
#   ('또', 'Noun'),
#   ('황정민', 'Noun'),
#   ('이네', 'Josa'),
#   ('보러', 'Verb'),
#   ('가', 'PreEomi'),
#   ('야', 'PreEomi'),
#   ('겠', 'PreEomi'),
#   ('네', 'Eomi')],
#  [('우와', 'Exclamation'),
#   ('강동원', 'Noun'),
#   ('머리', 'Noun'),
#   ('짧으', 'Adjective'),
#   ('니깐', 'Eomi'),
#   ('더', 'Noun'),
#   ('잘생겨', 'Adjective'),
#   ('보인', 'Verb'),
#   ('다', 'Eomi'),
#   ('ㅎㅎ', 'KoreanParticle')],
#  [('사랑해', 'Verb'), ('요', 'Eomi'), ('동원', 'Noun'), ('님', 'Suffix')],
#  [('으아아', 'Exclamation'),
#   ('아', 'Exclamation'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('나오면', 'Verb'),
#   ('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('가', 'PreEomi'),
#   ('야지', 'Eomi'),
#   ('슬픈', 'Adjective'),
#   ('건', 'Eomi'),
#   ('같이', 'Josa'),
#   ('갈', 'Verb'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('없다', 'Adjective')],
#  [('강동원', 'Noun'),
#   ('에', 'Josa'),
#   ('황정민', 'Noun'),
#   ('이라니', 'Josa'),
#   ('ㅠㅠㅠ', 'KoreanParticle'),
#   ('무조건', 'Noun'),
#   ('봐', 'Noun'),
#   ('야', 'Josa'),
#   ('돼', 'Verb')],
#  [('믿고', 'Verb'), ('보는', 'Verb'), ('배우', 'Noun'), ('황정민', 'Noun')],
#  [('ㅁㅊ', 'KoreanParticle'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('콤비', 'Noun'),
#   ('라니', 'Josa'),
#   ('이건', 'Noun'),
#   ('꼭봐', 'Noun'),
#   ('야', 'Josa'),
#   ('된', 'Verb'),
#   ('다', 'Eomi')],
#  [('동원', 'Noun'),
#   ('쓰', 'Verb'),
#   ('무슨', 'Noun'),
#   ('말', 'Noun'),
#   ('이', 'Josa'),
#   ('필요해', 'Adjective'),
#   ('모두', 'Noun'),
#   ('널', 'Noun'),
#   ('작품', 'Noun'),
#   ('이라고', 'Josa'),
#   ('불러', 'Verb')],
#  [('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('갈', 'Verb'),
#   ('예정', 'Noun'),
#   ('입니', 'Adjective'),
#   ('다', 'Eomi')],
#  [('신소율', 'Noun'),
#   ('이', 'Josa'),
#   ('정말', 'Noun'),
#   ('최고다', 'Noun'),
#   ('진짜', 'Noun')],
#  [('강동원', 'Noun'),
#   ('찬양', 'Noun'),
#   ('하라', 'Noun'),
#   ('찬미', 'Noun'),
#   ('하라', 'Noun'),
#   ('경배', 'Noun'),
#   ('하라', 'Noun'),
#   ('샹', 'Noun'),
#   ('ㅋㅋㅋ', 'KoreanParticle')],
#  [('당연히', 'Adjective'),
#   ('최소', 'Noun'),
#   ('다섯', 'Determiner'),
#   ('번', 'Noun'),
#   ('이', 'Suffix'),
#   ('지', 'Josa'),
#   ('무대', 'Noun'),
#   ('인사', 'Noun'),
#   ('꼭', 'Noun'),
#   ('갈', 'Verb'),
#   ('꺼', 'PreEomi'),
#   ('후기', 'Noun'),
#   ('남김', 'Verb')],
#  [('보고', 'Noun'),
#   ('안보', 'Noun'),
#   ('고', 'Josa'),
#   ('할', 'Verb'),
#   ('게', 'Eomi'),
#   ('뭐', 'Noun'),
#   ('가', 'Josa'),
#   ('있어', 'Adjective'),
#   ('당근', 'Noun'),
#   ('봐', 'Verb'),
#   ('야지', 'Eomi'),
#   ('갓', 'Noun'),
#   ('동원', 'Noun'),
#   ('님', 'Suffix'),
#   ('과', 'Josa'),
#   ('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('이성민', 'Noun'),
#   ('이', 'Josa'),
#   ('나오는', 'Verb'),
#   ('데', 'Eomi'),
#   ('갓', 'Noun'),
#   ('동원', 'Noun'),
#   ('님', 'Suffix'),
#   ('올해', 'Noun'),
#   ('영화', 'Noun'),
#   ('편', 'Noun'),
#   ('진짜', 'Noun'),
#   ('힘들', 'Adjective'),
#   ('겠', 'PreEomi'),
#   ('다', 'Eomi'),
#   ('그래도', 'Adverb'),
#   ('꼭', 'Noun'),
#   ('챙겨', 'Verb'),
#   ('볼게', 'Verb'),
#   ('요', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('이라는', 'Josa'),
#   ('데', 'Noun'),
#   ('안', 'VerbPrefix'),
#   ('볼', 'Verb'),
#   ('수', 'PreEomi'),
#   ('가', 'Eomi'),
#   ('없지', 'Adjective'),
#   ('박성웅', 'Noun'),
#   ('도', 'Josa'),
#   ('기대함', 'Adjective')],
#  [('강동원', 'Noun'),
#   ('진짜', 'Noun'),
#   ('믿', 'Verb'),
#   ('고본', 'Noun'),
#   ('다', 'Josa')],
#  [('이영화', 'Noun'),
#   ('는', 'Josa'),
#   ('재미있던', 'Adjective'),
#   ('없던', 'Adjective'),
#   ('흥행', 'Noun'),
#   ('성공한', 'Verb'),
#   ('다', 'Eomi'),
#   ('지금', 'Noun'),
#   ('볼', 'Noun'),
#   ('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('없어', 'Adjective'),
#   ('서', 'Eomi'),
#   ('죄다', 'Adverb'),
#   ('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('볼', 'Verb'),
#   ('듯', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('캐리', 'Noun'),
#   ('ㅋ', 'KoreanParticle'),
#   ('배꼽', 'Noun'),
#   ('빠짐', 'Verb'),
#   ('시사회', 'Noun'),
#   ('로', 'Josa'),
#   ('보고왔슴', 'Noun'),
#   ('다', 'Josa')],
#  [('식', 'Noun'), ('스크린', 'Noun'), ('독점', 'Noun'), ('짜증', 'Noun')],
#  [('두', 'Noun'),
#   ('명', 'Noun'),
#   ('배우', 'Noun'),
#   ('그', 'Determiner'),
#   ('중', 'Noun'),
#   ('에서도', 'Josa'),
#   ('황정민', 'Noun'),
#   ('이다', 'Josa'),
#   ('자', 'Noun'),
#   ('무엇', 'Noun'),
#   ('을', 'Josa'),
#   ('원하는', 'Verb'),
#   ('가', 'Eomi'),
#   ('그', 'Noun'),
#   ('이상', 'Noun'),
#   ('을', 'Josa'),
#   ('보게', 'Verb'),
#   ('될', 'Verb'),
#   ('것', 'PreEomi'),
#   ('이다', 'Eomi')],
#  [('월', 'Noun'),
#   ('일', 'Noun'),
#   ('대체', 'Noun'),
#   ('언제', 'Noun'),
#   ('오', 'Verb'),
#   ('나', 'PreEomi'),
#   ('여', 'Eomi')],
#  [('감독', 'Noun'),
#   ('님', 'Suffix'),
#   ('진짜', 'Noun'),
#   ('평타', 'Noun'),
#   ('만', 'Josa'),
#   ('쳐', 'Verb'),
#   ('줘', 'PreEomi'),
#   ('도', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('이', 'Suffix'),
#   ('면', 'Josa'),
#   ('천만', 'Noun'),
#   ('가능해', 'Adjective'),
#   ('요', 'Eomi'),
#   ('열일', 'Noun'),
#   ('부탁드림', 'Adjective'),
#   ('ㅠㅠ', 'KoreanParticle')],
#  [('둘', 'Noun'),
#   ('이', 'Josa'),
#   ('캐', 'Noun'),
#   ('미가', 'Noun'),
#   ('어떨', 'Adjective'),
#   ('지', 'Eomi'),
#   ('궁금하', 'Adjective'),
#   ('당', 'Eomi')],
#  [('우왕', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이래', 'Josa'),
#   ('꼭', 'Noun'),
#   ('봐', 'Verb'),
#   ('야지', 'Eomi')],
#  [('말', 'Noun'),
#   ('이', 'Josa'),
#   ('필요', 'Noun'),
#   ('없다', 'Adjective'),
#   ('강동원', 'Noun'),
#   ('이랑', 'Josa'),
#   ('황정민', 'Noun'),
#   ('이라니', 'Josa')],
#  [('강동원', 'Noun'),
#   ('은', 'Josa'),
#   ('사랑', 'Noun'),
#   ('입니', 'Adjective'),
#   ('다', 'Eomi')],
#  [('그냥', 'Noun'),
#   ('황정민', 'Noun'),
#   ('나오면', 'Verb'),
#   ('다', 'Adverb'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('음', 'Eomi'),
#   ('갓', 'Noun'),
#   ('정민', 'Noun')],
#  [('오오', 'Exclamation'),
#   ('또', 'Noun'),
#   ('황정민', 'Noun'),
#   ('의', 'Josa'),
#   ('영화', 'Noun'),
#   ('기대할', 'Adjective'),
#   ('께요', 'Eomi')],
#  [('강', 'Noun'), ('참치', 'Noun'), ('뭔들', 'Noun')],
#  [('이건', 'Noun'),
#   ('진짜', 'Noun'),
#   ('꼭봐', 'Noun'),
#   ('야', 'Josa'),
#   ('된', 'Verb'),
#   ('다', 'Eomi'),
#   ('ㅠㅠ', 'KoreanParticle')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('이건', 'Noun'),
#   ('말', 'Noun'),
#   ('이', 'Josa'),
#   ('필요없', 'Adjective'),
#   ('다', 'Eomi'),
#   ('극장', 'Noun'),
#   ('가서', 'Verb'),
#   ('바로', 'Noun'),
#   ('ㄱㄱ', 'KoreanParticle')],
#  [('개봉', 'Noun'),
#   ('언제', 'Noun'),
#   ('하나요', 'Noun'),
#   ('ㅜ', 'KoreanParticle'),
#   ('빨리', 'Adverb'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('어여', 'Eomi'),
#   ('ㅎ', 'KoreanParticle')],
#  [('황정민', 'Noun'),
#   ('이', 'Josa'),
#   ('젤', 'Noun'),
#   ('좋', 'Adjective'),
#   ('고', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('도', 'Josa'),
#   ('좋', 'Adjective'),
#   ('고', 'Eomi'),
#   ('기대되', 'Verb'),
#   ('네', 'Determiner'),
#   ('용', 'Noun'),
#   ('두근두근', 'Adverb')],
#  [('강동원', 'Noun'),
#   ('진짜', 'Noun'),
#   ('재', 'Noun'),
#   ('대', 'Suffix'),
#   ('한', 'Josa'),
#   ('이후', 'Noun'),
#   ('에', 'Josa'),
#   ('이렇게', 'Adverb'),
#   ('소', 'Noun'),
#   ('처럼', 'Josa'),
#   ('작품', 'Noun'),
#   ('많이', 'Adverb'),
#   ('해줘', 'Verb'),
#   ('서', 'Eomi'),
#   ('너무', 'Noun'),
#   ('고맙', 'Adjective'),
#   ('고', 'Eomi'),
#   ('사랑스럽', 'Adjective'),
#   ('다', 'Eomi'),
#   ('진짜', 'Noun'),
#   ('잘생겼', 'Adjective'),
#   ('고', 'Eomi'),
#   ('연기', 'Noun'),
#   ('도', 'Josa'),
#   ('잘', 'Verb'),
#   ('해', 'Noun'),
#   ('ㅠㅠㅠ', 'KoreanParticle'),
#   ('제발', 'Noun'),
#   ('영화', 'Noun'),
#   ('실망', 'Noun'),
#   ('스럽지', 'Josa'),
#   ('않기', 'Verb'),
#   ('를', 'Eomi')],
#  [('어제', 'Noun'),
#   ('촬영', 'Noun'),
#   ('한', 'Determiner'),
#   ('거', 'Noun'),
#   ('같은', 'Adjective'),
#   ('데', 'Eomi'),
#   ('벌써', 'Noun'),
#   ('개봉', 'Noun'),
#   ('제발', 'Noun'),
#   ('편집', 'Noun'),
#   ('많이', 'Adverb'),
#   ('안되', 'Verb'),
#   ('었', 'PreEomi'),
#   ('길', 'Eomi'),
#   ('담배', 'Noun'),
#   ('피는', 'Verb'),
#   ('장면', 'Noun'),
#   ('찝', 'Verb'),
#   ('을', 'Eomi'),
#   ('때', 'Noun'),
#   ('갑', 'Noun'),
#   ('정도', 'Noun'),
#   ('핀', 'Verb'),
#   ('거', 'Eomi'),
#   ('같다', 'Adjective'),
#   ('ㅋ', 'KoreanParticle')],
#  [('올해', 'Noun'),
#   ('첫', 'Noun'),
#   ('천만', 'Noun'),
#   ('관객', 'Noun'),
#   ('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('되', 'Verb'),
#   ('길', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('배우', 'Noun'),
#   ('님', 'Suffix'),
#   ('은', 'Josa'),
#   ('사랑', 'Noun'),
#   ('입니', 'Adjective'),
#   ('다', 'Eomi')],
#  [('강동원', 'Noun'), ('너무', 'Noun'), ('귀엽', 'Adjective'), ('다', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('이', 'Josa'),
#   ('나오는', 'Verb'),
#   ('건', 'Eomi'),
#   ('걍', 'Adverb'),
#   ('묻', 'Verb'),
#   ('지도', 'Eomi'),
#   ('따지', 'Verb'),
#   ('지도', 'Eomi'),
#   ('말고', 'Josa'),
#   ('보라', 'Noun'),
#   ('는', 'Josa'),
#   ('거', 'Noun'),
#   ('다', 'Josa'),
#   ('개봉', 'Noun'),
#   ('얼른', 'Noun'),
#   ('해랑', 'Noun')],
#  [('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('갈', 'Verb'),
#   ('께요', 'Eomi'),
#   ('ㅠㅠㅜㅠ', 'KoreanParticle'),
#   ('무대', 'Noun'),
#   ('인사', 'Noun'),
#   ('부산', 'Noun'),
#   ('에서도', 'Josa'),
#   ('해주세', 'Verb'),
#   ('용', 'Eomi'),
#   ('빨리', 'Adverb'),
#   ('개봉', 'Noun'),
#   ('합', 'Verb'),
#   ('시', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('님', 'Suffix'),
#   ('황정민', 'Noun'),
#   ('님', 'Suffix'),
#   ('연기력', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('후회', 'Noun'),
#   ('되', 'Verb'),
#   ('지', 'Eomi'),
#   ('않', 'Verb'),
#   ('을', 'Eomi'),
#   ('영화', 'Noun'),
#   ('될', 'Verb'),
#   ('듯', 'Eomi')],
#  [('갓', 'Noun'),
#   ('동원', 'Noun'),
#   ('오빠', 'Noun'),
#   ('껑', 'Noun'),
#   ('걍', 'Adverb'),
#   ('좋', 'Adjective'),
#   ('아요', 'Eomi')],
#  [('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('잘', 'VerbPrefix'),
#   ('뽑았', 'Verb'),
#   ('다', 'Eomi')],
#  [('스크린', 'Noun'),
#   ('독점', 'Noun'),
#   ('대박', 'Noun'),
#   ('예매할', 'Verb'),
#   ('려고', 'Eomi'),
#   ('했', 'Verb'),
#   ('는데', 'Eomi'),
#   ('관수', 'Noun'),
#   ('엄청', 'Adverb'),
#   ('많이', 'Adverb'),
#   ('잡은', 'Verb'),
#   ('거', 'Eomi'),
#   ('보고', 'Noun'),
#   ('놀람', 'Noun'),
#   ('이건', 'Noun'),
#   ('좀', 'Noun'),
#   ('아니', 'Adjective'),
#   ('다', 'Eomi'),
#   ('재미', 'Noun'),
#   ('유무', 'Noun'),
#   ('를', 'Josa'),
#   ('떠나서', 'Verb'),
#   ('너무', 'Noun'),
#   ('하다', 'Verb'),
#   ('싶네', 'Verb')],
#  [('이일형', 'Noun'),
#   ('감독', 'Noun'),
#   ('님', 'Suffix'),
#   ('화이팅', 'Noun'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이라니', 'Josa'),
#   ('벌써', 'Noun'),
#   ('부터', 'Noun'),
#   ('기대되', 'Verb'),
#   ('네요', 'Eomi')],
#  [('한국', 'Noun'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('영화', 'Noun'),
#   ('보는', 'Verb'),
#   ('눈', 'Noun'),
#   ('이', 'Josa'),
#   ('점점', 'Noun'),
#   ('썩는', 'Verb'),
#   ('거', 'Eomi'),
#   ('같다', 'Adjective'),
#   ('어', 'Noun'),
#   ('째', 'Suffix')],
#  [('개꿀잼', 'Noun'),
#   ('한편', 'Noun'),
#   ('의', 'Josa'),
#   ('한국', 'Noun'),
#   ('화', 'Suffix'),
#   ('한', 'Josa'),
#   ('명작', 'Noun'),
#   ('외국', 'Noun'),
#   ('영화', 'Noun'),
#   ('보는', 'Verb'),
#   ('느낌', 'Noun'),
#   ('코믹', 'Noun'),
#   ('화이트', 'Noun'),
#   ('칙스', 'Noun'),
#   ('급', 'Suffix'),
#   ('한국', 'Noun'),
#   ('코믹', 'Noun'),
#   ('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('이', 'Determiner'),
#   ('정도', 'Noun'),
#   ('로', 'Josa'),
#   ('성장할', 'Verb'),
#   ('줄', 'PreEomi'),
#   ('은', 'Eomi'),
#   ('몰랐', 'Verb'),
#   ('음', 'Eomi'),
#   ('정말', 'Noun'),
#   ('탄탄', 'Noun'),
#   ('한', 'Josa'),
#   ('스토리', 'Noun'),
#   ('에', 'Josa'),
#   ('현실', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('모습', 'Noun'),
#   ('을', 'Josa'),
#   ('잘', 'Verb'),
#   ('풍자', 'Noun'),
#   ('해냈', 'Verb'),
#   ('음', 'Eomi')],
#  [('김시', 'Noun'),
#   ('영영', 'Noun'),
#   ('화', 'Suffix'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('어요', 'Eomi'),
#   ('신청', 'Noun')],
#  [('이', 'Noun'),
#   ('캐스팅', 'Noun'),
#   ('을', 'Josa'),
#   ('보고', 'Noun'),
#   ('도', 'Josa'),
#   ('안', 'Noun'),
#   ('볼', 'Noun'),
#   ('수가', 'Noun'),
#   ('있', 'Adjective'),
#   ('나', 'Eomi')],
#  [('동원', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('내', 'Noun'),
#   ('가', 'Josa'),
#   ('천만', 'Noun'),
#   ('만들어', 'Verb'),
#   ('줄', 'PreEomi'),
#   ('게요', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('죄수', 'Noun'),
#   ('핏', 'Noun'),
#   ('감상하러', 'Verb'),
#   ('갑', 'Verb'),
#   ('니다', 'Eomi')],
#  [('취업', 'Noun'),
#   ('하고', 'Josa'),
#   ('보러', 'Verb'),
#   ('간다', 'Noun'),
#   ('꼭', 'Noun')],
#  [('박성웅', 'Noun'),
#   ('도', 'Josa'),
#   ('나오네', 'Verb'),
#   ('ㅋㅋ', 'KoreanParticle'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi')],
#  [('와', 'Noun'),
#   ('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('대박', 'Noun'),
#   ('ㄷㄷㄷㄷ', 'KoreanParticle')],
#  [('죄수복', 'Noun'),
#   ('도', 'Josa'),
#   ('잘', 'VerbPrefix'),
#   ('어울리', 'Verb'),
#   ('네', 'Eomi'),
#   ('참치', 'Noun'),
#   ('오빠', 'Suffix'),
#   ('사랑해', 'Verb'),
#   ('요', 'Eomi')],
#  [('극장', 'Noun'),
#   ('에서', 'Josa'),
#   ('꼭', 'Noun'),
#   ('보겠', 'Verb'),
#   ('습니다', 'Eomi')],
#  [('브라더', 'Noun'),
#   ('장난', 'Noun'),
#   ('아니', 'Adjective'),
#   ('구마', 'Noun'),
#   ('잉', 'Noun')],
#  [('황정민', 'Noun'), ('박성웅', 'Noun'), ('다시', 'Noun'), ('만나네', 'Verb')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('캐', 'Noun'),
#   ('미', 'Adjective'),
#   ('쩔', 'Verb'),
#   ('듯', 'Eomi'),
#   ('겁나', 'Verb'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('ㅠ', 'KoreanParticle')],
#  [('최고', 'Noun'),
#   ('의', 'Josa'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('의', 'Josa'),
#   ('명품', 'Noun'),
#   ('연기', 'Noun'),
#   ('기대', 'Noun'),
#   ('돼', 'Verb'),
#   ('요', 'Eomi')],
#  [('동원', 'Noun'),
#   ('짱', 'Suffix'),
#   ('ㅜㅜㅠㅠ', 'KoreanParticle'),
#   ('얼른', 'Noun'),
#   ('개봉', 'Noun'),
#   ('만', 'Josa'),
#   ('해', 'Noun'),
#   ('라', 'Josa')],
#  [('근데', 'Adverb'),
#   ('신의한수', 'Noun'),
#   ('삘', 'Noun'),
#   ('나긴', 'Verb'),
#   ('한데', 'Eomi'),
#   ('재미있', 'Adjective'),
#   ('을', 'PreEomi'),
#   ('것', 'PreEomi'),
#   ('같다', 'Adjective')],
#  [('강동원', 'Noun'), ('황정민', 'Noun'), ('ㄷㄷㄷㄷ', 'KoreanParticle')],
#  [('강동원', 'Noun'),
#   ('나오면', 'Verb'),
#   ('보러', 'Verb'),
#   ('가', 'PreEomi'),
#   ('겟', 'PreEomi'),
#   ('습', 'Noun'),
#   ('니', 'Josa'),
#   ('댜', 'Noun'),
#   ('기대할', 'Adjective'),
#   ('게요', 'Eomi')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('이라니', 'Josa'),
#   ('이', 'Noun'),
#   ('영화', 'Noun'),
#   ('캐스팅', 'Noun'),
#   ('때', 'Noun'),
#   ('부터', 'Josa'),
#   ('기다렸', 'Verb'),
#   ('는데', 'Eomi'),
#   ('언제', 'Noun'),
#   ('개봉', 'Noun'),
#   ('하려', 'Verb'),
#   ('나', 'Eomi'),
#   ('수능', 'Noun'),
#   ('끝나고', 'Verb'),
#   ('면', 'Eomi'),
#   ('더', 'Noun'),
#   ('좋', 'Adjective'),
#   ('겠', 'PreEomi'),
#   ('다', 'Adverb'),
#   ('ㅋㅋㅋㅋ', 'KoreanParticle'),
#   ('브로맨스', 'Noun'),
#   ('면', 'Josa'),
#   ('더', 'Noun'),
#   ('좋', 'Adjective'),
#   ('겠', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('신소율', 'Noun'),
#   ('씨', 'Suffix'),
#   ('연기', 'Noun'),
#   ('너무', 'Noun'),
#   ('잘해서', 'Verb'),
#   ('검색', 'Noun'),
#   ('해봤', 'Verb'),
#   ('는대', 'Eomi'),
#   ('좋', 'Adjective'),
#   ('은', 'Eomi'),
#   ('영화', 'Noun'),
#   ('기대하겠', 'Adjective'),
#   ('습니다', 'Eomi'),
#   ('캐스팅', 'Noun'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('짱', 'Noun'),
#   ('짱', 'Suffix'),
#   ('하내', 'Noun'),
#   ('요', 'Josa')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('소재', 'Noun'),
#   ('모두', 'Noun'),
#   ('흥미롭', 'Adjective'),
#   ('지만', 'Eomi'),
#   ('감독', 'Noun'),
#   ('에서', 'Josa'),
#   ('기대', 'Noun'),
#   ('치가', 'Noun')],
#  [('황정민', 'Noun'),
#   ('배우', 'Noun'),
#   ('님', 'Suffix'),
#   ('의', 'Josa'),
#   ('활약', 'Noun'),
#   ('이', 'Josa'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('이', 'Determiner'),
#   ('번영', 'Noun'),
#   ('화', 'Suffix'),
#   ('도', 'Josa'),
#   ('대박', 'Noun'),
#   ('치', 'Verb'),
#   ('길', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('은', 'Josa'),
#   ('부당거래', 'Noun'),
#   ('때', 'Noun'),
#   ('부터', 'Josa'),
#   ('비리', 'Noun'),
#   ('있는', 'Adjective'),
#   ('경찰', 'Noun'),
#   ('같은', 'Adjective'),
#   ('역', 'Noun'),
#   ('은', 'Josa'),
#   ('참', 'Verb'),
#   ('잘한', 'Verb'),
#   ('단', 'Eomi'),
#   ('말', 'Noun'),
#   ('이지', 'Noun'),
#   ('ㅋㅋㅋㅋ', 'KoreanParticle')],
#  [('갓', 'Noun'),
#   ('동원', 'Noun'),
#   ('과', 'Josa'),
#   ('갓', 'Noun'),
#   ('정민', 'Noun'),
#   ('의', 'Josa'),
#   ('케미', 'Noun'),
#   ('기대하겠', 'Adjective'),
#   ('습니다', 'Eomi')],
#  [('만', 'Noun'), ('각', 'Noun'), ('이다', 'Josa'), ('이', 'Noun'), ('영화', 'Noun')],
#  [('와', 'Verb'),
#   ('이', 'PreEomi'),
#   ('건', 'Eomi'),
#   ('꼭', 'Noun'),
#   ('봐', 'Verb'),
#   ('야', 'PreEomi'),
#   ('해', 'Eomi'),
#   ('ㄷㄷㄷ', 'KoreanParticle')],
#  [('캐스팅', 'Noun'),
#   ('지리', 'Noun'),
#   ('네', 'Josa'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('원', 'Suffix'),
#   ('에', 'Josa'),
#   ('이성민', 'Noun'),
#   ('거기', 'Noun'),
#   ('다', 'Josa'),
#   ('개취', 'Noun'),
#   ('로', 'Josa'),
#   ('제일', 'Noun'),
#   ('좋아하는', 'Adjective'),
#   ('여배우', 'Noun'),
#   ('신소율', 'Noun'),
#   ('까지', 'Josa'),
#   ('무조건', 'Noun'),
#   ('보러', 'Verb'),
#   ('간다', 'Noun')],
#  [('강동원', 'Noun'),
#   ('의', 'Josa'),
#   ('귀여운', 'Adjective'),
#   ('사기꾼', 'Noun'),
#   ('그', 'Determiner'),
#   ('이상', 'Noun'),
#   ('도', 'Josa'),
#   ('그', 'Noun'),
#   ('이하', 'Noun'),
#   ('도', 'Josa'),
#   ('아니', 'Adjective'),
#   ('다', 'Eomi'),
#   ('영화관', 'Noun'),
#   ('에선', 'Josa'),
#   ('이상', 'Noun'),
#   ('까르르', 'Noun'),
#   ('까르르', 'Noun'),
#   ('여자', 'Noun'),
#   ('들', 'Suffix'),
#   ('웃음소리', 'Noun'),
#   ('만', 'Josa'),
#   ('새', 'Verb'),
#   ('어', 'Eomi'),
#   ('나왔', 'Verb'),
#   ('다', 'Eomi'),
#   ('같은', 'Adjective'),
#   ('여자', 'Noun'),
#   ('지만', 'Josa'),
#   ('그', 'Determiner'),
#   ('정도', 'Noun'),
#   ('로', 'Josa'),
#   ('웃긴', 'Verb'),
#   ('건', 'Eomi'),
#   ('아닌', 'Adjective'),
#   ('거', 'Eomi'),
#   ('같은', 'Adjective'),
#   ('데', 'Eomi'),
#   ('전', 'Noun'),
#   ('대초', 'Noun'),
#   ('반', 'Noun'),
#   ('대초', 'Noun'),
#   ('반', 'Noun'),
#   ('풋풋', 'Noun'),
#   ('한', 'Josa'),
#   ('여자', 'Noun'),
#   ('들', 'Suffix'),
#   ('에게', 'Josa'),
#   ('먹힐', 'Verb'),
#   ('영화', 'Noun')],
#  [('아직', 'Noun'),
#   ('도', 'Josa'),
#   ('이런', 'Adjective'),
#   ('영화', 'Noun'),
#   ('에', 'Josa'),
#   ('흥미', 'Noun'),
#   ('를', 'Josa'),
#   ('느끼', 'Verb'),
#   ('고', 'PreEomi'),
#   ('싶', 'PreEomi'),
#   ('나', 'Eomi'),
#   ('이', 'Determiner'),
#   ('젠', 'Noun'),
#   ('영화', 'Noun'),
#   ('내용', 'Noun'),
#   ('보다', 'Josa'),
#   ('배우', 'Noun'),
#   ('한테', 'Josa'),
#   ('의지해서', 'Verb'),
#   ('영화', 'Noun'),
#   ('를', 'Josa'),
#   ('만들어', 'Verb'),
#   ('야', 'PreEomi'),
#   ('겟', 'PreEomi'),
#   ('냐', 'Eomi'),
#   ('구', 'Noun'),
#   ('이런', 'Adjective'),
#   ('영화', 'Noun'),
#   ('는', 'Josa'),
#   ('극장', 'Noun'),
#   ('말고', 'Josa'),
#   ('로', 'Noun'),
#   ('봐', 'Noun'),
#   ('넥플', 'Noun'),
#   ('다음', 'Noun'),
#   ('에', 'Josa')],
#  [('월', 'Noun'),
#   ('일', 'Noun'),
#   ('잡아', 'Verb'),
#   ('서', 'Eomi'),
#   ('기다려', 'Verb'),
#   ('야지', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('감동', 'Noun'),
#   ('원', 'Suffix'),
#   ('둘', 'Noun'),
#   ('다', 'Josa'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('실수', 'Noun'),
#   ('로', 'Josa'),
#   ('글쎄요', 'Noun'),
#   ('누름', 'Verb'),
#   ('ㅠㅠ', 'KoreanParticle'),
#   ('개봉', 'Noun'),
#   ('하면', 'Verb'),
#   ('바로', 'Noun'),
#   ('보러', 'Verb'),
#   ('갈', 'Verb'),
#   ('게요', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('짱', 'Suffix')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('의', 'Josa'),
#   ('연기력', 'Noun'),
#   ('이', 'Josa'),
#   ('관객', 'Noun'),
#   ('들', 'Suffix'),
#   ('을', 'Josa'),
#   ('기대되', 'Verb'),
#   ('게', 'Eomi'),
#   ('만드는', 'Verb'),
#   ('영화인', 'Noun'),
#   ('것', 'Noun'),
#   ('같', 'Adjective'),
#   ('습니다', 'Eomi'),
#   ('검사', 'Noun'),
#   ('외전', 'Noun'),
#   ('화이팅', 'Noun')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('박성웅', 'Noun'),
#   ('이성민', 'Noun'),
#   ('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('제대로', 'Noun'),
#   ('흥행', 'Noun'),
#   ('하겠', 'Verb'),
#   ('내', 'PreEomi'),
#   ('ㅋㅋㅋ', 'KoreanParticle')],
#  [('천만', 'Noun'),
#   ('배우', 'Noun'),
#   ('황정민', 'Noun'),
#   ('믿', 'Verb'),
#   ('고본', 'Noun'),
#   ('다', 'Josa'),
#   ('무조건', 'Noun'),
#   ('재밋', 'Noun'),
#   ('다', 'Josa')],
#  [('올해', 'Noun'),
#   ('가장', 'Noun'),
#   ('재밌는', 'Adjective'),
#   ('숨은', 'Verb'),
#   ('명작', 'Noun'),
#   ('이', 'Josa'),
#   ('될', 'Verb'),
#   ('듯', 'Eomi')],
#  [('내', 'Noun'),
#   ('가', 'Josa'),
#   ('좋아하는', 'Adjective'),
#   ('범죄', 'Noun'),
#   ('오락', 'Noun'),
#   ('에', 'Josa'),
#   ('내', 'Noun'),
#   ('가', 'Josa'),
#   ('좋아하는', 'Adjective'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('신소율', 'Noun'),
#   ('기대하겠', 'Adjective'),
#   ('습니다', 'Eomi')],
#  [('이건', 'Noun'),
#   ('꼭', 'Noun'),
#   ('봅', 'Verb'),
#   ('니다', 'Eomi'),
#   ('ㅜㅜ', 'KoreanParticle'),
#   ('강동원', 'Noun'),
#   ('과', 'Josa'),
#   ('황정민', 'Noun'),
#   ('이라니', 'Josa'),
#   ('ㅜㅜ', 'KoreanParticle')],
#  [('기대하고', 'Adjective'),
#   ('보는', 'Verb'),
#   ('황정민', 'Noun'),
#   ('응원', 'Noun'),
#   ('할', 'Verb'),
#   ('게요', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이다', 'Josa'),
#   ('빨리', 'Adverb'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('지금', 'Noun'),
#   ('리본', 'Noun'),
#   ('타워', 'Noun'),
#   ('단지', 'Noun'),
#   ('앞', 'Noun'),
#   ('에서', 'Josa'),
#   ('촬영', 'Noun'),
#   ('중', 'Suffix')],
#  [('기분', 'Noun'),
#   ('개꿀', 'Noun'),
#   ('강동원', 'Noun'),
#   ('영화', 'Noun'),
#   ('두', 'Determiner'),
#   ('개', 'Noun'),
#   ('찍는', 'Verb'),
#   ('다', 'Eomi'),
#   ('기분', 'Noun'),
#   ('짱', 'Noun'),
#   ('좋', 'Adjective'),
#   ('다', 'Eomi'),
#   ('개', 'Noun'),
#   ('행복', 'Noun')],
#  [('강동원', 'Noun'),
#   ('년', 'Noun'),
#   ('팬', 'Noun'),
#   ('으로써', 'Josa'),
#   ('이번', 'Noun'),
#   ('영화', 'Noun'),
#   ('도', 'Josa'),
#   ('당연히', 'Adjective')],
#  [('개봉', 'Noun'),
#   ('언제', 'Noun'),
#   ('해', 'Josa'),
#   ('요', 'Noun'),
#   ('빨리', 'Adverb'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('다', 'Eomi'),
#   ('ㅜㅜㅡ', 'KoreanParticle')],
#  [('영화', 'Noun'),
#   ('잘', 'Verb'),
#   ('나오길', 'Verb'),
#   ('기대할', 'Adjective'),
#   ('께요', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('영화', 'Noun'),
#   ('는', 'Josa'),
#   ('믿고', 'Verb'),
#   ('볼', 'Noun'),
#   ('만', 'Josa'),
#   ('함', 'Noun')],
#  [('완전', 'Noun'),
#   ('이번', 'Noun'),
#   ('에도', 'Josa'),
#   ('황정민', 'Noun'),
#   ('천만배', 'Noun'),
#   ('우등', 'Noun'),
#   ('극', 'Suffix'),
#   ('ㅡ', 'KoreanParticle'),
#   ('그냥', 'Noun'),
#   ('안봐', 'Noun'),
#   ('도', 'Josa'),
#   ('어떤', 'Adjective'),
#   ('내용', 'Noun'),
#   ('인지', 'Josa'),
#   ('알', 'Verb'),
#   ('거', 'Eomi'),
#   ('같', 'Adjective'),
#   ('애', 'Noun'),
#   ('요', 'Josa'),
#   ('ㅎㅎ', 'KoreanParticle')],
#  [('강동원', 'Noun'),
#   ('황정민', 'Noun'),
#   ('오빠', 'Noun'),
#   ('들', 'Suffix'),
#   ('ㅋㅋㅋㅋ', 'KoreanParticle'),
#   ('쉬', 'Verb'),
#   ('긴', 'Eomi'),
#   ('하세', 'Verb'),
#   ('요', 'Eomi'),
#   ('ㅎㅎㅎ', 'KoreanParticle'),
#   ('영화', 'Noun'),
#   ('보러', 'Verb'),
#   ('가', 'PreEomi'),
#   ('는', 'Eomi'),
#   ('곳', 'Noun'),
#   ('마다', 'Josa'),
#   ('꼭', 'Noun'),
#   ('있어', 'Adjective'),
#   ('ㅋㅋㅋ', 'KoreanParticle'),
#   ('진짜', 'Noun'),
#   ('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('배우', 'Verb'),
#   ('이', 'PreEomi'),
#   ('므로', 'Eomi'),
#   ('영화', 'Noun'),
#   ('스토리', 'Noun'),
#   ('가', 'Josa'),
#   ('개망작', 'Noun'),
#   ('만', 'Josa'),
#   ('아니', 'Adjective'),
#   ('면', 'Eomi'),
#   ('기본', 'Noun'),
#   ('은', 'Josa'),
#   ('걍', 'Adverb'),
#   ('넘', 'Verb'),
#   ('을', 'PreEomi'),
#   ('듯', 'Eomi'),
#   ('ㅋ', 'KoreanParticle')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이', 'Josa'),
#   ('모두', 'Noun'),
#   ('나온', 'Verb'),
#   ('다니', 'Eomi'),
#   ('ㅠㅜ', 'KoreanParticle'),
#   ('거기', 'Noun'),
#   ('다', 'Josa'),
#   ('내', 'Noun'),
#   ('가', 'Josa'),
#   ('좋아하는', 'Adjective'),
#   ('범죄', 'Noun'),
#   ('오락', 'Noun'),
#   ('장르', 'Noun'),
#   ('꿀잼', 'Noun'),
#   ('예약', 'Noun'),
#   ('거기', 'Noun'),
#   ('다', 'Josa'),
#   ('강동원', 'Noun'),
#   ('이', 'Josa'),
#   ('사기꾼', 'Noun'),
#   ('황정민', 'Noun'),
#   ('연기력', 'Noun'),
#   ('은', 'Josa'),
#   ('뭐', 'Noun'),
#   ('말할', 'Verb'),
#   ('것', 'PreEomi'),
#   ('도', 'Eomi'),
#   ('없구', 'Adjective'),
#   ('ㅎㅎ', 'KoreanParticle'),
#   ('너무', 'Noun'),
#   ('기대된', 'Verb'),
#   ('다', 'Eomi'),
#   ('개봉', 'Noun'),
#   ('첫날', 'Noun'),
#   ('에', 'Josa'),
#   ('꼭', 'Noun'),
#   ('보러', 'Verb'),
#   ('갈', 'Verb'),
#   ('게요', 'Eomi'),
#   ('ㅋㅋ', 'KoreanParticle'),
#   ('검사', 'Noun'),
#   ('외전', 'Noun'),
#   ('응원', 'Noun'),
#   ('해', 'Josa'),
#   ('요', 'Noun'),
#   ('천만', 'Noun'),
#   ('갑', 'Verb'),
#   ('시', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('이건무', 'Noun'),
#   ('조건', 'Noun'),
#   ('봐', 'Noun'),
#   ('야한', 'Adjective'),
#   ('다', 'Eomi'),
#   ('볼', 'Verb'),
#   ('지', 'PreEomi'),
#   ('안', 'PreEomi'),
#   ('볼', 'Verb'),
#   ('지', 'PreEomi'),
#   ('가', 'PreEomi'),
#   ('아', 'PreEomi'),
#   ('니라', 'Eomi'),
#   ('몇번', 'Noun'),
#   ('볼', 'Verb'),
#   ('지를', 'Eomi'),
#   ('결정', 'Noun'),
#   ('해', 'Josa'),
#   ('야함', 'Adjective')],
#  [('두', 'Noun'),
#   ('배우', 'Noun'),
#   ('의', 'Josa'),
#   ('존재', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('천만', 'Noun'),
#   ('가능', 'Noun'),
#   ('ㅎ', 'KoreanParticle')],
#  [('뭐', 'Noun'),
#   ('냐', 'Josa'),
#   ('재밌겠', 'Adjective'),
#   ('다', 'Eomi'),
#   ('ㅋㅋㅋㅋ', 'KoreanParticle')],
#  [('강동원', 'Noun'),
#   ('때문', 'Noun'),
#   ('에', 'Josa'),
#   ('반드시', 'Noun'),
#   ('본', 'Verb'),
#   ('다', 'Eomi')],
#  [('최고', 'Noun'),
#   ('의', 'Josa'),
#   ('영화', 'Noun'),
#   ('다', 'Josa'),
#   ('의', 'Noun'),
#   ('신의', 'Noun'),
#   ('한수', 'Noun')],
#  [('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('그냥', 'Noun'),
#   ('일단', 'Noun'),
#   ('천만', 'Noun'),
#   ('각', 'Noun'),
#   ('이다', 'Josa')],
#  [('티켓파워', 'Noun'),
#   ('배우', 'Noun'),
#   ('외', 'Noun'),
#   ('에는', 'Josa'),
#   ('그다지', 'Noun'),
#   ('건질', 'Verb'),
#   ('만', 'Eomi'),
#   ('한', 'Determiner'),
#   ('게', 'Noun'),
#   ('없다', 'Adjective'),
#   ('배급사', 'Noun'),
#   ('의', 'Josa'),
#   ('상술', 'Noun'),
#   ('이', 'Josa'),
#   ('고스', 'Noun'),
#   ('란', 'Noun'),
#   ('히', 'Adverb'),
#   ('나타난', 'Verb'),
#   ('또', 'Noun'),
#   ('하나', 'Noun'),
#   ('의', 'Josa'),
#   ('공산품', 'Noun')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('의', 'Josa'),
#   ('매력', 'Noun'),
#   ('을', 'Josa'),
#   ('최대로', 'Noun'),
#   ('활용한', 'Verb'),
#   ('영화', 'Noun'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('매력', 'Noun'),
#   ('에', 'Josa'),
#   ('흠뻑', 'Noun'),
#   ('빠져', 'Verb'),
#   ('들', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('영화인', 'Noun'),
#   ('것', 'Noun'),
#   ('같아', 'Adjective'),
#   ('요', 'Eomi'),
#   ('조금', 'Noun'),
#   ('아쉬운', 'Adjective'),
#   ('부분', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('아예', 'Noun'),
#   ('없다', 'Adjective'),
#   ('면', 'Eomi'),
#   ('거짓말', 'Noun'),
#   ('이지만', 'Josa'),
#   ('감독', 'Noun'),
#   ('님', 'Suffix'),
#   ('의', 'Josa'),
#   ('입', 'Noun'),
#   ('봉작', 'Noun'),
#   ('이라', 'Josa'),
#   ('는걸', 'Noun'),
#   ('감안', 'Noun'),
#   ('하면', 'Verb'),
#   ('훌륭한', 'Adjective'),
#   ('수준', 'Noun'),
#   ('이지', 'Noun'),
#   ('않', 'Verb'),
#   ('나', 'Eomi'),
#   ('싶', 'Verb'),
#   ('습니다', 'Eomi')],
#  [('시사회', 'Noun'),
#   ('로', 'Josa'),
#   ('보고', 'Noun'),
#   ('왔', 'Verb'),
#   ('는데', 'Eomi'),
#   ('범죄물', 'Noun'),
#   ('이라기보단', 'Josa'),
#   ('대놓고', 'Adverb'),
#   ('코믹', 'Noun'),
#   ('물', 'Verb'),
#   ('인', 'PreEomi'),
#   ('듯', 'Eomi'),
#   ('ㅋㅋㅋㅋ', 'KoreanParticle'),
#   ('내용', 'Noun'),
#   ('은', 'Josa'),
#   ('베테', 'Noun'),
#   ('랑', 'Josa'),
#   ('내', 'Determiner'),
#   ('부자', 'Noun'),
#   ('들', 'Suffix'),
#   ('과', 'Josa'),
#   ('비슷하', 'Adjective'),
#   ('나', 'Eomi'),
#   ('너무', 'Noun'),
#   ('웃김', 'Verb'),
#   ('캐릭터', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('왠만한', 'Adjective'),
#   ('코믹', 'Noun'),
#   ('영화', 'Noun'),
#   ('보다', 'Josa'),
#   ('웃기', 'Noun'),
#   ('고', 'Josa'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('그걸', 'Adverb'),
#   ('참', 'Verb'),
#   ('잘', 'VerbPrefix'),
#   ('표현하는', 'Verb'),
#   ('듯', 'Eomi'),
#   ('연기력', 'Noun'),
#   ('과', 'Josa'),
#   ('웃음', 'Noun'),
#   ('으로', 'Josa'),
#   ('시나리오', 'Noun'),
#   ('의', 'Josa'),
#   ('부족', 'Noun'),
#   ('을', 'Josa'),
#   ('채워', 'Verb'),
#   ('줌', 'Noun')],
#  [('황정민', 'Noun'),
#   ('은', 'Josa'),
#   ('황정민', 'Noun'),
#   ('다운', 'Noun'),
#   ('연기', 'Noun'),
#   ('였', 'Verb'),
#   ('고', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('은', 'Josa'),
#   ('매우', 'Noun'),
#   ('능글', 'Noun'),
#   ('맞고', 'Verb'),
#   ('빵빵', 'Noun'),
#   ('터짐', 'Verb'),
#   ('ㅋㅋ', 'KoreanParticle'),
#   ('조연', 'Noun'),
#   ('으로', 'Josa'),
#   ('나온', 'Verb'),
#   ('박성웅', 'Noun'),
#   ('도', 'Josa'),
#   ('깨알', 'Noun'),
#   ('웃음', 'Noun'),
#   ('ㅋㅋ', 'KoreanParticle'),
#   ('개인', 'Noun'),
#   ('차는', 'Verb'),
#   ('있겠', 'Adjective'),
#   ('지만', 'Eomi'),
#   ('재밌게', 'Adjective'),
#   ('봤', 'Verb'),
#   ('습니다', 'Eomi'),
#   ('내', 'Determiner'),
#   ('부자', 'Noun'),
#   ('들', 'Suffix'),
#   ('은', 'Josa'),
#   ('잔인', 'Noun'),
#   ('하고', 'Josa'),
#   ('그래서', 'Adverb'),
#   ('가족', 'Noun'),
#   ('들', 'Suffix'),
#   ('끼리', 'Noun'),
#   ('보기', 'Noun'),
#   ('가', 'Josa'),
#   ('좀', 'Noun'),
#   ('그랬는데', 'Conjunction'),
#   ('이건', 'Noun'),
#   ('부모님', 'Noun'),
#   ('들', 'Suffix'),
#   ('이나', 'Josa'),
#   ('자녀', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('같이', 'Josa'),
#   ('보기', 'Noun'),
#   ('좋', 'Adjective'),
#   ('은', 'Eomi'),
#   ('영화', 'Noun'),
#   ('네', 'Suffix'),
#   ('요', 'Josa')],
#  [('평론가', 'Noun'),
#   ('들', 'Suffix'),
#   ('평론', 'Noun'),
#   ('보', 'Noun'),
#   ('니까', 'Josa'),
#   ('딱', 'VerbPrefix'),
#   ('봐', 'Verb'),
#   ('도', 'Eomi'),
#   ('그냥', 'Noun'),
#   ('킬링타임', 'Noun'),
#   ('용', 'Noun'),
#   ('오락', 'Noun'),
#   ('영화', 'Noun'),
#   ('수준', 'Noun'),
#   ('이네', 'Josa'),
#   ('티켓파워', 'Noun'),
#   ('있는', 'Adjective'),
#   ('배우', 'Noun'),
#   ('빨', 'Noun'),
#   ('영화', 'Noun'),
#   ('일', 'Noun'),
#   ('가능성', 'Noun'),
#   ('이', 'Josa'),
#   ('농후', 'Noun')],
#  [('이번', 'Noun'),
#   ('설연휴', 'Noun'),
#   ('에', 'Josa'),
#   ('진짜', 'Noun'),
#   ('볼', 'Noun'),
#   ('만', 'Suffix'),
#   ('한', 'Josa'),
#   ('영화', 'Noun'),
#   ('는', 'Josa'),
#   ('쿵푸팬더', 'Noun'),
#   ('밖에', 'Josa'),
#   ('없는', 'Adjective'),
#   ('데', 'Eomi'),
#   ('이건', 'Noun'),
#   ('덤', 'Noun'),
#   ('으로', 'Josa'),
#   ('그냥', 'Noun'),
#   ('울며', 'Verb'),
#   ('겨자', 'Noun'),
#   ('먹기', 'Noun'),
#   ('식', 'Suffix'),
#   ('으로', 'Josa'),
#   ('막', 'Noun'),
#   ('보겠', 'Verb'),
#   ('군', 'Eomi'),
#   ('진짜', 'Noun'),
#   ('한국영', 'Noun'),
#   ('화', 'Suffix'),
#   ('노답', 'Noun'),
#   ('헐리웃', 'Noun'),
#   ('영화', 'Noun'),
#   ('랑', 'Josa'),
#   ('한국영', 'Noun'),
#   ('화', 'Suffix'),
#   ('랑', 'Josa'),
#   ('왜', 'Noun'),
#   ('같은', 'Adjective'),
#   ('관람', 'Noun'),
#   ('료', 'Noun'),
#   ('를', 'Josa'),
#   ('받지', 'Verb'),
#   ('어이', 'Noun'),
#   ('없어', 'Adjective')],
#  [('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이성민', 'Noun')],
#  [('사실', 'Noun'),
#   ('재밌', 'Adjective'),
#   ('을', 'PreEomi'),
#   ('것', 'PreEomi'),
#   ('같긴', 'Adjective'),
#   ('한데', 'Eomi'),
#   ('또', 'Noun'),
#   ('막상', 'Noun'),
#   ('개봉', 'Noun'),
#   ('하면', 'Verb'),
#   ('개봉', 'Noun'),
#   ('전', 'Noun'),
#   ('부터', 'Josa'),
#   ('너무', 'Noun'),
#   ('이슈', 'Noun'),
#   ('화', 'Suffix'),
#   ('됐', 'Verb'),
#   ('고', 'Eomi'),
#   ('우리', 'Noun'),
#   ('가', 'Josa'),
#   ('받은', 'Verb'),
#   ('기', 'Noun'),
#   ('대감', 'Noun'),
#   ('이', 'Josa'),
#   ('너무', 'Noun'),
#   ('커서', 'Noun'),
#   ('실망할', 'Verb'),
#   ('까봐', 'Eomi'),
#   ('그게', 'Noun'),
#   ('걱정', 'Noun'),
#   ('ㅠㅠ', 'KoreanParticle')],
#  [('개봉', 'Noun'),
#   ('당일', 'Noun'),
#   ('이', 'Josa'),
#   ('졸업식', 'Noun'),
#   ('인데', 'Josa'),
#   ('졸업식', 'Noun'),
#   ('끝나고', 'Verb'),
#   ('바로', 'Noun'),
#   ('달려갑', 'Verb'),
#   ('니다', 'Eomi'),
#   ('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('듣', 'Verb'),
#   ('자마자', 'Eomi'),
#   ('봐', 'Verb'),
#   ('야', 'PreEomi'),
#   ('겠', 'PreEomi'),
#   ('다는', 'Eomi'),
#   ('생각', 'Noun'),
#   ('이', 'Josa'),
#   ('들었', 'Verb'),
#   ('는데', 'Eomi'),
#   ('예고편', 'Noun'),
#   ('까지', 'Josa'),
#   ('이리', 'Adverb'),
#   ('대박', 'Noun'),
#   ('이니', 'Josa'),
#   ('안', 'VerbPrefix'),
#   ('볼', 'Verb'),
#   ('수', 'PreEomi'),
#   ('가', 'Eomi'),
#   ('없네', 'Adjective'),
#   ('여', 'Eomi'),
#   ('ㅠㅠ', 'KoreanParticle'),
#   ('사랑해', 'Verb'),
#   ('요', 'Eomi'),
#   ('검사', 'Noun'),
#   ('외전', 'Noun'),
#   ('꼭', 'Noun'),
#   ('천만', 'Noun'),
#   ('가길', 'Verb')],
#  [('하루', 'Noun'),
#   ('앞', 'Noun'),
#   ('당겨', 'Verb'),
#   ('져서', 'Eomi'),
#   ('완전', 'Noun'),
#   ('더', 'Noun'),
#   ('좋', 'Adjective'),
#   ('다', 'Eomi')],
#  [('황정민', 'Noun'), ('강동원', 'Noun'), ('기대합', 'Adjective'), ('니다', 'Eomi')],
#  [('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('벌써', 'Noun'),
#   ('보러', 'Verb'),
#   ('가', 'Eomi'),
#   ('자고', 'Noun'),
#   ('이야기하네', 'Verb'),
#   ('요', 'Eomi'),
#   ('좌석', 'Noun'),
#   ('확보', 'Noun'),
#   ('가', 'Josa'),
#   ('관건', 'Noun'),
#   ('일', 'Verb'),
#   ('듯', 'Eomi'),
#   ('합', 'Verb'),
#   ('니다', 'Eomi'),
#   ('눈빛', 'Noun'),
#   ('빛나는', 'Verb'),
#   ('두', 'Noun'),
#   ('배우', 'Noun'),
#   ('보는', 'Verb'),
#   ('것', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('행복', 'Noun'),
#   ('일', 'Verb'),
#   ('듯', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('엄청', 'Adverb'),
#   ('좋아하는', 'Adjective'),
#   ('데', 'Eomi'),
#   ('너무', 'Noun'),
#   ('다작', 'Noun'),
#   ('하는', 'Verb'),
#   ('것', 'PreEomi'),
#   ('아닌', 'Adjective'),
#   ('감', 'Noun')],
#  [('황정민', 'Noun'), ('천만', 'Noun'), ('가자', 'Verb'), ('아자', 'Exclamation')],
#  [('네네', 'Noun'),
#   ('ㅠ', 'KoreanParticle'),
#   ('나수니', 'Noun'),
#   ('보러', 'Verb'),
#   ('갑', 'Verb'),
#   ('니다', 'Eomi'),
#   ('ㅠㅜ', 'KoreanParticle'),
#   ('이', 'Noun'),
#   ('야', 'Exclamation'),
#   ('밤', 'Noun'),
#   ('에', 'Josa'),
#   ('티저', 'Noun'),
#   ('로', 'Josa'),
#   ('폭행', 'Noun'),
#   ('당', 'Suffix'),
#   ('해', 'Josa'),
#   ('너덜너덜', 'Adverb'),
#   ('한', 'Determiner'),
#   ('심장', 'Noun'),
#   ('부여', 'Noun'),
#   ('잡고', 'Noun'),
#   ('터져', 'Verb'),
#   ('버릴', 'Verb'),
#   ('꺼', 'PreEomi'),
#   ('야', 'Eomi'),
#   ('지금', 'Noun'),
#   ('부터', 'Josa'),
#   ('겨울잠', 'Noun'),
#   ('자서', 'Noun'),
#   ('월', 'Noun'),
#   ('일', 'Noun'),
#   ('에', 'Josa'),
#   ('일어나고', 'Noun'),
#   ('싶다', 'Verb'),
#   ('진심', 'Noun'),
#   ('두', 'Noun'),
#   ('배우', 'Noun'),
#   ('의', 'Josa'),
#   ('케미', 'Noun'),
#   ('지', 'Verb'),
#   ('짜', 'Verb'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi'),
#   ('하진', 'Noun'),
#   ('짜', 'Verb'),
#   ('잠', 'Verb'),
#   ('이', 'PreEomi'),
#   ('안', 'PreEomi'),
#   ('와', 'Eomi'),
#   ('미친', 'Adjective'),
#   ('레드불', 'Noun'),
#   ('저리', 'Noun'),
#   ('가라', 'Verb'),
#   ('고', 'PreEomi'),
#   ('해', 'Eomi'),
#   ('ㅠㅜ', 'KoreanParticle')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('강동원', 'Noun'),
#   ('의', 'Josa'),
#   ('케미', 'Noun'),
#   ('가', 'Josa'),
#   ('기대되', 'Verb'),
#   ('네요', 'Eomi'),
#   ('강동원', 'Noun'),
#   ('배우', 'Noun'),
#   ('님', 'Suffix'),
#   ('덕분', 'Noun'),
#   ('에', 'Josa'),
#   ('이', 'Noun'),
#   ('영화', 'Noun'),
#   ('최소', 'Noun'),
#   ('번은', 'Noun'),
#   ('볼', 'Verb'),
#   ('것', 'PreEomi'),
#   ('같네', 'Adjective'),
#   ('요', 'Eomi'),
#   ('ㅎㅎ', 'KoreanParticle')],
#  [('재미있', 'Adjective'),
#   ('을', 'Eomi'),
#   ('것', 'Noun'),
#   ('같아', 'Adjective'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('언제', 'Noun'),
#   ('개', 'Suffix'),
#   ('봉하', 'Noun'),
#   ('지', 'Josa'),
#   ('ㅠㅠㅠㅠ', 'KoreanParticle')],
#  [('황정민', 'Noun'),
#   ('강동원', 'Noun'),
#   ('이성민', 'Noun'),
#   ('다', 'Adverb'),
#   ('내', 'Noun'),
#   ('가', 'Josa'),
#   ('사랑하는', 'Verb'),
#   ('연기', 'Noun'),
# ...
#   ('겠지', 'Verb'),
#   ('만', 'Eomi'),
#   ('실제', 'Noun'),
#   ('영화', 'Noun'),
#   ('도', 'Josa'),
#   ('대박', 'Noun'),
#   ('임', 'Noun'),
#   ('무엇', 'Noun'),
#   ('보다', 'Josa'),
#   ('천우희', 'Noun'),
#   ('는', 'Josa'),
#   ('요즘', 'Noun'),
#   ('계속', 'Noun'),
#   ('사람', 'Noun'),
#   ('놀라게', 'Verb'),
#   ('하', 'PreEomi'),
#   ('네', 'Eomi'),
#   ('ㅋ', 'KoreanParticle')],
#  [('이건', 'Noun'),
#   ('무조건', 'Noun'),
#   ('극장', 'Noun'),
#   ('에서', 'Josa'),
#   ('봐', 'Noun'),
#   ('야', 'Josa'),
#   ('할', 'Verb'),
#   ('영화', 'Noun')],
#  [('기대', 'Noun'),
#   ('이상', 'Noun'),
#   ('의', 'Josa'),
#   ('탄탄', 'Noun'),
#   ('하고', 'Josa'),
#   ('심장', 'Noun'),
#   ('쫄깃', 'Noun'),
#   ('한', 'Josa'),
#   ('연출', 'Noun'),
#   ('ㅋㅋ', 'KoreanParticle'),
#   ('보는', 'Verb'),
#   ('내내', 'Noun'),
#   ('긴장', 'Noun'),
#   ('을', 'Josa'),
#   ('늦출', 'Verb'),
#   ('수', 'Noun'),
#   ('없', 'Adjective'),
#   ('엇다', 'Eomi')],
#  [('나홍진', 'Noun'),
#   ('감독', 'Noun'),
#   ('작품', 'Noun'),
#   ('개', 'Noun'),
#   ('중', 'Noun'),
#   ('역대', 'Noun'),
#   ('급', 'Suffix')],
#  [('무엇', 'Noun'),
#   ('보다', 'Josa'),
#   ('곽도원', 'Noun'),
#   ('과', 'Josa'),
#   ('그', 'Noun'),
#   ('의', 'Josa'),
#   ('딸', 'Noun'),
#   ('연기', 'Noun'),
#   ('가', 'Josa'),
#   ('일품', 'Noun')],
#  [('방금', 'Noun'),
#   ('갓', 'Noun'),
#   ('동진', 'Noun'),
#   ('님', 'Suffix'),
#   ('이', 'Josa'),
#   ('만점', 'Noun'),
#   ('을', 'Josa'),
#   ('주셨', 'Verb'),
#   ('다', 'Eomi'),
#   ('거의', 'Noun'),
#   ('살인', 'Noun'),
#   ('의', 'Josa'),
#   ('추억', 'Noun'),
#   ('급', 'Suffix'),
#   ('이라는', 'Josa'),
#   ('거', 'Noun'),
#   ('네', 'Josa'),
#   ('팬티', 'Noun'),
#   ('들', 'Suffix'),
#   ('챙기', 'Verb'),
#   ('세요', 'Eomi')],
#  [('나', 'Noun'),
#   ('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('할머니', 'Noun'),
#   ('네', 'Josa'),
#   ('가다가', 'Noun'),
#   ('촬영', 'Noun'),
#   ('하는', 'Verb'),
#   ('거', 'Eomi'),
#   ('봤', 'Verb'),
#   ('었', 'PreEomi'),
#   ('는데', 'Eomi'),
#   ('무슨', 'Noun'),
#   ('영환', 'Noun'),
#   ('지', 'Josa'),
#   ('말', 'Noun'),
#   ('안', 'VerbPrefix'),
#   ('해주던', 'Verb'),
#   ('데', 'Eomi'),
#   ('ㅋㅋ', 'KoreanParticle'),
#   ('곡성', 'Noun'),
#   ('이', 'Josa'),
#   ('였', 'Verb'),
#   ('으', 'PreEomi')],
#  [('배우', 'Noun'),
#   ('감독', 'Noun'),
#   ('ㅋ', 'KoreanParticle'),
#   ('무조건', 'Noun'),
#   ('점', 'Noun'),
#   ('드림', 'Noun')],
#  [('오랫동안', 'Noun'),
#   ('기다린', 'Verb'),
#   ('만큼', 'Noun'),
#   ('훌륭한', 'Adjective'),
#   ('작품', 'Noun'),
#   ('이', 'Josa'),
#   ('탄생하길', 'Verb'),
#   ('바랄', 'Verb'),
#   ('게요', 'Eomi')],
#  [('나홍진', 'Noun'),
#   ('의', 'Josa'),
#   ('스릴러', 'Noun'),
#   ('영화', 'Noun'),
#   ('라면', 'Noun'),
#   ('무조건', 'Noun'),
#   ('믿고', 'Verb'),
#   ('볼', 'Noun'),
#   ('수', 'Noun'),
#   ('있지', 'Adjective'),
#   ('요', 'Eomi')],
#  [('랑', 'Josa'),
#   ('비슷한', 'Adjective'),
#   ('느낌', 'Noun'),
#   ('이라', 'Josa'),
#   ('기대됨', 'Verb'),
#   ('둘', 'Noun'),
#   ('다', 'Josa'),
#   ('같이', 'Josa'),
#   ('개봉', 'Noun'),
#   ('했', 'Verb'),
#   ('으면', 'Eomi'),
#   ('좋', 'Adjective'),
#   ('겠', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('설마', 'Noun'),
#   ('천우희', 'Noun'),
#   ('가', 'Josa'),
#   ('귀신', 'Noun'),
#   ('이라', 'Josa'),
#   ('거나', 'Noun'),
#   ('외부', 'Noun'),
#   ('인', 'Suffix'),
#   ('에', 'Josa'),
#   ('대한', 'Noun'),
#   ('낯선', 'Noun'),
#   ('공포', 'Noun'),
#   ('심', 'Noun'),
#   ('으로', 'Josa'),
#   ('엉뚱한', 'Adjective'),
#   ('사람', 'Noun'),
#   ('을', 'Josa'),
#   ('범인', 'Noun'),
#   ('으로', 'Josa'),
#   ('몰고', 'Verb'),
#   ('가', 'PreEomi'),
#   ('고', 'Eomi'),
#   ('하는', 'Verb'),
#   ('류', 'Noun'),
#   ('의', 'Josa'),
#   ('메시지', 'Noun'),
#   ('이', 'Determiner'),
#   ('거나', 'Noun'),
#   ('동조', 'Noun'),
#   ('효과', 'Noun'),
#   ('의', 'Josa'),
#   ('문제점', 'Noun'),
#   ('을', 'Josa'),
#   ('지적하는', 'Verb'),
#   ('류', 'Noun'),
#   ('의', 'Josa'),
#   ('영화', 'Noun'),
#   ('는', 'Josa'),
#   ('아니', 'Adjective'),
#   ('겠', 'PreEomi'),
#   ('지', 'Eomi')],
#  [('드디어', 'Noun'), ('나오네', 'Verb'), ('요', 'Eomi')],
#  [('어떤', 'Adjective'),
#   ('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('나올', 'Verb'),
#   ('지', 'Eomi'),
#   ('완전', 'Noun'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('대박', 'Noun'),
#   ('완전', 'Noun'),
#   ('기대', 'Noun'),
#   ('입니', 'Adjective'),
#   ('다', 'Eomi'),
#   ('다', 'Adverb'),
#   ('너무', 'Noun'),
#   ('좋아하는', 'Adjective'),
#   ('분들', 'Suffix'),
#   ('글', 'Noun'),
#   ('고', 'Josa'),
#   ('진짜', 'Noun'),
#   ('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('나홍진', 'Noun'),
#   ('감독', 'Noun'),
#   ('님', 'Suffix'),
#   ('작품', 'Noun'),
#   ('오오오', 'Noun')],
#  [('곡성', 'Noun'),
#   ('은', 'Josa'),
#   ('그냥', 'Noun'),
#   ('무조건', 'Noun'),
#   ('무조건', 'Noun'),
#   ('이야', 'Josa')],
#  [('황해', 'Noun'),
#   ('추격자', 'Noun'),
#   ('최고', 'Noun'),
#   ('였', 'Verb'),
#   ('다', 'Eomi'),
#   ('이제', 'Noun'),
#   ('기다리', 'Verb'),
#   ('기만', 'Eomi'),
#   ('하면', 'Verb'),
#   ('된', 'Verb'),
#   ('다', 'Eomi')],
#  [('캐스팅', 'Noun'),
#   ('되', 'Verb'),
#   ('고', 'Eomi'),
#   ('거의', 'Noun'),
#   ('년', 'Noun'),
#   ('반', 'Noun'),
#   ('을', 'Josa'),
#   ('기다렸', 'Verb'),
#   ('네요', 'Eomi'),
#   ('엄청', 'Adverb'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('감독', 'Noun'),
#   ('과', 'Josa'),
#   ('출연', 'Noun'),
#   ('진', 'Noun'),
#   ('만으로', 'Josa'),
#   ('점임', 'Noun')],
#  [('많이', 'Adverb'),
#   ('기대하고', 'Adjective'),
#   ('있', 'Adjective'),
#   ('습니다', 'Eomi')],
#  [('이제', 'Noun'),
#   ('서야', 'Verb'),
#   ('개봉', 'Noun'),
#   ('을', 'Josa'),
#   ('하네', 'Verb')],
#  [('벌써', 'Noun'),
#   ('부터', 'Josa'),
#   ('대작', 'Noun'),
#   ('의', 'Josa'),
#   ('스', 'Noun'),
#   ('멜', 'Verb'),
#   ('이', 'Eomi'),
#   ('물씬', 'Noun'),
#   ('배우', 'Noun'),
#   ('감독', 'Noun'),
#   ('모두', 'Noun'),
#   ('너무', 'Noun'),
#   ('기대', 'Noun'),
#   ('시나리오', 'Noun'),
#   ('진짜', 'Noun'),
#   ('쥭', 'Noun'),
#   ('인', 'Suffix'),
#   ('다', 'Josa'),
#   ('던데', 'Noun')],
#  [('아', 'Exclamation'),
#   ('드디어', 'Noun'),
#   ('나왔', 'Verb'),
#   ('구만', 'Eomi'),
#   ('너무', 'Noun'),
#   ('궁', 'Noun'),
#   ('금보', 'Noun'),
#   ('고', 'Josa'),
#   ('싶다', 'Verb')],
#  [('나홍진', 'Noun'),
#   ('감독', 'Noun'),
#   ('의', 'Josa'),
#   ('신작', 'Noun'),
#   ('이', 'Determiner'),
#   ('것', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('볼', 'Noun'),
#   ('만', 'Noun'),
#   ('한', 'Josa'),
#   ('이유', 'Noun'),
#   ('가', 'Josa'),
#   ('있다', 'Adjective')],
#  [('오', 'Noun'),
#   ('이', 'Determiner'),
#   ('거', 'Noun'),
#   ('완전', 'Noun'),
#   ('기대', 'Noun'),
#   ('중', 'Suffix'),
#   ('인', 'Josa'),
#   ('영화', 'Noun'),
#   ('임', 'Noun')],
#  [('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('구려', 'Eomi'),
#   ('최고', 'Noun'),
#   ('일', 'Verb'),
#   ('듯', 'Eomi')],
#  [('나홍진', 'Noun'),
#   ('감독', 'Noun'),
#   ('에', 'Josa'),
#   ('황정민', 'Noun'),
#   ('천우희', 'Noun'),
#   ('캐스팅', 'Noun'),
#   ('대박', 'Noun'),
#   ('인', 'Josa'),
#   ('듯', 'Noun')],
#  [('아', 'Exclamation'),
#   ('진심', 'Noun'),
#   ('빨리', 'Adverb'),
#   ('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('다', 'Eomi'),
#   ('ㅠㅠㅠ', 'KoreanParticle')],
#  [('드디어', 'Noun'),
#   ('개봉', 'Noun'),
#   ('하는', 'Verb'),
#   ('구나', 'Noun'),
#   ('ㅠㅠㅠㅠ', 'KoreanParticle'),
#   ('레알', 'Noun'),
#   ('이다', 'Josa')],
#  [('엄청', 'Adverb'),
#   ('기다리', 'Verb'),
#   ('고', 'Eomi'),
#   ('있었', 'Adjective'),
#   ('는데', 'Eomi'),
#   ('드디어', 'Noun'),
#   ('월', 'Noun'),
#   ('에', 'Josa'),
#   ('개봉', 'Noun'),
#   ('하는', 'Verb'),
#   ('구나', 'Eomi'),
#   ('감독', 'Noun'),
#   ('부터', 'Josa'),
#   ('배우', 'Noun'),
#   ('까지', 'Josa'),
#   ('믿고', 'Verb'),
#   ('보는', 'Verb'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('다', 'Adverb'),
#   ('모였', 'Verb'),
#   ('네', 'Eomi')],
#  [('나홍진', 'Noun'),
#   ('이라', 'Josa'),
#   ('믿고', 'Verb'),
#   ('준', 'Noun'),
#   ('다', 'Josa')],
#  [('드뎌', 'Noun'),
#   ('개봉', 'Noun'),
#   ('날짜', 'Noun'),
#   ('정해졌', 'Verb'),
#   ('네요', 'Eomi'),
#   ('월', 'Noun'),
#   ('일', 'Noun'),
#   ('엄청', 'Adverb'),
#   ('기대', 'Noun'),
#   ('됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('언제', 'Noun'), ('나옵', 'Verb'), ('니까', 'Eomi')],
#  [('우리', 'Noun'),
#   ('집', 'Noun'),
#   ('옥상', 'Noun'),
#   ('에서', 'Josa'),
#   ('스탭들', 'Noun'),
#   ('이', 'Josa'),
#   ('촬영', 'Noun'),
#   ('하고', 'Josa'),
#   ('우리', 'Noun'),
#   ('옆집', 'Noun'),
#   ('에서', 'Josa'),
#   ('촬영', 'Noun'),
#   ('한', 'Determiner'),
#   ('거', 'Noun'),
#   ('라', 'Josa'),
#   ('더욱', 'Noun'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi'),
#   ('우리', 'Noun'),
#   ('옆집', 'Noun'),
#   ('나온', 'Verb'),
#   ('다는데', 'Eomi'),
#   ('영화', 'Noun'),
#   ('야', 'Josa'),
#   ('당연히', 'Adjective'),
#   ('흥행', 'Noun'),
#   ('하겠', 'Verb'),
#   ('지만', 'Eomi'),
#   ('재미없', 'Adjective'),
#   ('어도', 'Eomi'),
#   ('볼', 'Noun'),
#   ('겁니', 'Verb'),
#   ('자', 'Eomi')],
#  [('황정민', 'Noun'),
#   ('과', 'Josa'),
#   ('곽도원', 'Noun'),
#   ('이라', 'Josa'),
#   ('ㅋㅋㅋ', 'KoreanParticle'),
#   ('시너지', 'Noun'),
#   ('지릴듯', 'Noun'),
#   ('ㄷㄷㄷ', 'KoreanParticle'),
#   ('게다가', 'Noun'),
#   ('추격자', 'Noun'),
#   ('나홍진', 'Noun'),
#   ('의', 'Josa'),
#   ('신', 'Noun'),
#   ('작', 'Noun'),
#   ('이라니', 'Josa'),
#   ('ㅎㅎㅋㅋ', 'KoreanParticle'),
#   ('아', 'Exclamation'),
#   ('기대도', 'Verb'),
#   ('는구나', 'Eomi'),
#   ('ㅎㅎㅎ', 'KoreanParticle'),
#   ('빨리', 'Adverb'),
#   ('개봉', 'Noun'),
#   ('해', 'Noun'),
#   ('라', 'Josa'),
#   ('ㅎㅎㅎ', 'KoreanParticle'),
#   ('천만', 'Noun'),
#   ('예상', 'Noun'),
#   ('성', 'Noun'),
#   ('지', 'Verb'),
#   ('글', 'Noun')],
#  [('아무리', 'Adverb'),
#   ('생각해도', 'Verb'),
#   ('황해', 'Noun'),
#   ('는', 'Verb'),
#   ('너무나', 'Noun'),
#   ('훌륭한', 'Adjective'),
#   ('작품', 'Noun'),
#   ('입니', 'Adjective'),
#   ('다', 'Eomi'),
#   ('지금', 'Noun'),
#   ('번째', 'Suffix'),
#   ('또', 'Noun'),
#   ('보는', 'Verb'),
#   ('중', 'Noun'),
#   ('쿠니', 'Noun'),
#   ('무', 'Noun'),
#   ('라', 'Josa'),
#   ('준', 'Noun'),
#   ('은', 'Noun'),
#   ('나', 'Noun'),
#   ('감독', 'Noun'),
#   ('의', 'Josa'),
#   ('영화', 'Noun'),
#   ('를', 'Josa'),
#   ('보고', 'Noun'),
#   ('출연', 'Noun'),
#   ('결정', 'Noun'),
#   ('한', 'Determiner'),
#   ('것', 'Noun'),
#   ('아닐', 'Adjective'),
#   ('까', 'Eomi'),
#   ('요', 'Noun')],
#  [('곡성', 'Noun'),
#   ('건', 'Noun'),
#   ('들', 'Suffix'),
#   ('지', 'Josa'),
#   ('말', 'Verb'),
#   ('란', 'Eomi'),
#   ('말', 'Noun'),
#   ('이', 'Suffix'),
#   ('에여', 'Josa'),
#   ('ㅠ', 'KoreanParticle')],
#  [('천우희', 'Noun'),
#   ('님', 'Suffix'),
#   ('보러', 'Verb'),
#   ('꼭', 'Noun'),
#   ('갈거', 'Verb'),
#   ('에요', 'Eomi'),
#   ('제발', 'Noun'),
#   ('빨리', 'Adverb'),
#   ('개봉', 'Noun'),
#   ('ㅠㅠㅠ', 'KoreanParticle')],
#  [('천우희', 'Noun'), ('진짜', 'Noun'), ('이쁘', 'Adjective'), ('다', 'Eomi')],
#  [('빨리', 'Adverb'),
#   ('개봉', 'Noun'),
#   ('해주세', 'Verb'),
#   ('요', 'Eomi'),
#   ('현기증', 'Noun'),
#   ('난', 'Verb'),
#   ('단', 'Eomi'),
#   ('말', 'Noun'),
#   ('이', 'Suffix'),
#   ('예요', 'Josa')],
#  [('조한철', 'Noun'),
#   ('님', 'Suffix'),
#   ('연기', 'Noun'),
#   ('가', 'Josa'),
#   ('기대됩', 'Verb'),
#   ('니다', 'Eomi')],
#  [('곡성', 'Noun'),
#   ('영화', 'Noun'),
#   ('관계자', 'Noun'),
#   ('분', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('신거', 'Verb'),
#   ('같은', 'Adjective'),
#   ('데', 'Eomi'),
#   ('저희', 'Noun'),
#   ('카페', 'Noun'),
#   ('도', 'Josa'),
#   ('자주', 'Noun'),
#   ('오시', 'Noun'),
#   ('고', 'Josa'),
#   ('제', 'Noun'),
#   ('가', 'Josa'),
#   ('사는', 'Verb'),
#   ('지역', 'Noun'),
#   ('이라', 'Josa'),
#   ('진짜', 'Noun'),
#   ('많은', 'Adjective'),
#   ('관심', 'Noun'),
#   ('이', 'Josa'),
#   ('가네', 'Verb'),
#   ('요', 'Eomi'),
#   ('도움', 'Noun'),
#   ('될', 'Verb'),
#   ('게', 'Eomi'),
#   ('있으', 'Adjective'),
#   ('면', 'Eomi'),
#   ('해드리', 'Verb'),
#   ('고', 'Eomi'),
#   ('싶은', 'Verb'),
#   ('정도', 'Noun'),
#   ('네', 'Suffix'),
#   ('요', 'Josa'),
#   ('기대하고', 'Adjective'),
#   ('있으', 'Adjective'),
#   ('니', 'Eomi'),
#   ('잘', 'Verb'),
#   ('만들어', 'Verb'),
#   ('졌', 'Verb'),
#   ('으면', 'Eomi'),
#   ('좋', 'Adjective'),
#   ('겠', 'PreEomi'),
#   ('습니다', 'Eomi'),
#   ('화이팅', 'Noun')],
#  [('대박', 'Noun'),
#   ('ㅋ', 'KoreanParticle'),
#   ('곡성', 'Noun'),
#   ('에서', 'Josa'),
#   ('영화', 'Noun'),
#   ('찍', 'Noun'),
#   ('나', 'Josa'),
#   ('보네', 'Verb'),
#   ('ㅋㅋㅋ', 'KoreanParticle')],
#  [('곡성', 'Noun'),
#   ('우리', 'Noun'),
#   ('할', 'Verb'),
#   ('매집', 'Noun'),
#   ('인데', 'Josa'),
#   ('언제', 'Noun'),
#   ('진짜', 'Noun'),
#   ('로', 'Josa'),
#   ('곡성', 'Noun'),
#   ('에서', 'Josa'),
#   ('찍는', 'Verb'),
#   ('다면', 'Eomi'),
#   ('기사', 'Noun'),
#   ('좀', 'Noun'),
#   ('내주', 'Verb'),
#   ('셈', 'Eomi'),
#   ('찾아가서', 'Verb'),
#   ('구경하게', 'Verb'),
#   ('ㅎㅎㅎ', 'KoreanParticle')],
#  [('박평', 'Noun'),
#   ('식이', 'Noun'),
#   ('점', 'Noun'),
#   ('이동진', 'Noun'),
#   ('이', 'Josa'),
#   ('점', 'Noun'),
#   ('닥치고', 'Noun'),
#   ('보자', 'Verb')],
#  [('나오는', 'Verb'),
#   ('배우', 'Noun'),
#   ('분들', 'Suffix'),
#   ('하나같이', 'Adverb'),
#   ('모두', 'Noun'),
#   ('연기력', 'Noun'),
#   ('장난', 'Noun'),
#   ('아님', 'Adjective'),
#   ('특히', 'Adverb'),
#   ('곽도원', 'Noun'),
#   ('은', 'Josa'),
#   ('미친', 'Adjective'),
#   ('듯', 'Eomi')],
#  [('내일', 'Noun'),
#   ('영화관', 'Noun'),
#   ('에', 'Josa'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('어마', 'Exclamation'),
#   ('어마', 'Exclamation'),
#   ('할', 'Verb'),
#   ('듯', 'Eomi')],
#  [('곡성', 'Noun'),
#   ('이라', 'Josa'),
#   ('쓰', 'Verb'),
#   ('고', 'Eomi'),
#   ('탄성', 'Noun'),
#   ('이라', 'Josa'),
#   ('읽는', 'Verb'),
#   ('다', 'Eomi')],
#  [('영화', 'Noun'),
#   ('악마', 'Noun'),
#   ('를', 'Josa'),
#   ('보았', 'Verb'),
#   ('다', 'PreEomi'),
#   ('와', 'Eomi'),
#   ('검은', 'Adjective'),
#   ('사제', 'Noun'),
#   ('들', 'Suffix'),
#   ('을', 'Josa'),
#   ('합쳐', 'Verb'),
#   ('놓', 'PreEomi'),
#   ('은', 'Eomi'),
#   ('듯', 'Noun'),
#   ('한', 'Josa'),
#   ('분위기', 'Noun'),
#   ('의', 'Josa'),
#   ('영화', 'Noun'),
#   ('였', 'Verb'),
#   ('다', 'Eomi'),
#   ('시사회', 'Noun'),
#   ('무대', 'Noun'),
#   ('인사', 'Noun'),
#   ('때', 'Noun'),
#   ('곽도원', 'Noun'),
#   ('주연', 'Noun'),
#   ('배우', 'Noun'),
#   ('의', 'Josa'),
#   ('말', 'Noun'),
#   ('처럼', 'Josa'),
#   ('심장', 'Noun'),
#   ('이', 'Josa'),
#   ('쫄깃해', 'Noun'),
#   ('지는', 'Josa'),
#   ('스릴', 'Noun'),
#   ('을', 'Josa'),
#   ('경험', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('걸작', 'Noun'),
#   ('이었', 'Verb'),
#   ('다', 'Eomi'),
#   ('현혹', 'Noun'),
#   ('되', 'Verb'),
#   ('지', 'Eomi'),
#   ('않고', 'Verb'),
#   ('진실', 'Noun'),
#   ('에', 'Josa'),
#   ('도달할', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('관객', 'Noun'),
#   ('이', 'Josa'),
#   ('있다', 'Adjective'),
#   ('면', 'Eomi'),
#   ('감', 'Noun'),
#   ('이', 'Josa'),
#   ('정말', 'Noun'),
#   ('좋', 'Adjective'),
#   ('은', 'Eomi'),
#   ('사람', 'Noun'),
#   ('이다', 'Josa')],
#  [('끝', 'Noun'),
#   ('까지', 'Josa'),
#   ('시계', 'Noun'),
#   ('한번', 'Noun'),
#   ('안보', 'Noun'),
#   ('고', 'Josa'),
#   ('감상한', 'Verb'),
#   ('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('얼마', 'Noun'),
#   ('만이', 'Noun'),
#   ('냐', 'Josa'),
#   ('완전히', 'Adjective'),
#   ('압도', 'Noun'),
#   ('당했', 'Adjective'),
#   ('다', 'Eomi')],
#  [('시사회', 'Noun'),
#   ('보고', 'Noun'),
#   ('왔', 'Verb'),
#   ('다', 'Eomi'),
#   ('나홍진', 'Noun'),
#   ('이라', 'Josa'),
#   ('쓰', 'Verb'),
#   ('고', 'Eomi'),
#   ('천재', 'Noun'),
#   ('라', 'Josa'),
#   ('읽는', 'Verb'),
#   ('다', 'Eomi'),
#   ('시간', 'Noun'),
#   ('분', 'Noun'),
#   ('런닝', 'Noun'),
#   ('타임', 'Noun'),
#   ('분', 'Noun'),
#   ('초가', 'Noun'),
#   ('쫄리', 'Noun'),
#   ('고', 'Josa'),
#   ('쫄림', 'Noun'),
#   ('어찌', 'Noun'),
#   ('이리', 'Adverb'),
#   ('쫀쫀하', 'Noun'),
#   ('게', 'Josa'),
#   ('만들었', 'Verb'),
#   ('는지', 'Eomi'),
#   ('시나리오', 'Noun'),
#   ('발상', 'Noun'),
#   ('자체', 'Noun'),
#   ('가', 'Josa'),
#   ('일반', 'Noun'),
#   ('적임', 'Noun'),
#   ('을', 'Josa'),
#   ('벗어', 'Verb'),
#   ('난', 'Eomi'),
#   ('소재', 'Noun'),
#   ('와', 'Josa'),
#   ('스토리', 'Noun'),
#   ('라인', 'Noun'),
#   ('숨막히는', 'Adjective'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('의', 'Josa'),
#   ('연기력', 'Noun'),
#   ('터지', 'Verb'),
#   ('고', 'Eomi'),
#   ('한장', 'Noun'),
#   ('면', 'Josa'),
#   ('한장', 'Noun'),
#   ('면', 'Josa'),
#   ('놓칠', 'Verb'),
#   ('수', 'PreEomi'),
#   ('없는', 'Adjective'),
#   ('긴장감', 'Noun')],
#  [('정말로', 'Adverb'), ('재미있어', 'Adjective'), ('요', 'Eomi')],
#  [('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('연기', 'Noun'),
#   ('쩔더', 'Verb'),
#   ('라', 'Eomi'),
#   ('황정민', 'Noun'),
#   ('진짜', 'Noun'),
#   ('대단한', 'Adjective'),
#   ('듯', 'Eomi'),
#   ('소름', 'Noun'),
#   ('돋는', 'Adjective'),
#   ('연기', 'Noun')],
#  [('보고', 'Verb'),
#   ('싶', 'PreEomi'),
#   ('어서', 'Eomi'),
#   ('미칠', 'Adjective'),
#   ('거', 'Eomi'),
#   ('같다', 'Adjective')],
#  [('감독', 'Noun'),
#   ('님', 'Suffix'),
#   ('대구', 'Noun'),
#   ('까지', 'Josa'),
#   ('와', 'Verb'),
#   ('주', 'PreEomi'),
#   ('시', 'PreEomi'),
#   ('다니', 'Eomi'),
#   ('감격', 'Noun'),
#   ('그', 'Determiner'),
#   ('자체', 'Noun')],
#  [('캡틴아메리카', 'Noun'),
#   ('점준', 'Noun'),
#   ('박평', 'Noun'),
#   ('식이', 'Noun'),
#   ('점', 'Noun'),
#   ('줬', 'Verb'),
#   ('다', 'Eomi'),
#   ('믿고', 'Verb'),
#   ('봅', 'Verb'),
#   ('시', 'PreEomi'),
#   ('다', 'Eomi')],
#  [('재밋엇음', 'Noun'),
#   ('근데', 'Adverb'),
#   ('생각', 'Noun'),
#   ('보다', 'Josa'),
#   ('무섭', 'Adjective')],
#  [('왠지', 'Adverb'),
#   ('영화', 'Noun'),
#   ('소름', 'Noun'),
#   ('하고', 'Josa'),
#   ('분위기', 'Noun'),
#   ('가', 'Josa'),
#   ('비슷할', 'Adjective'),
#   ('듯', 'Eomi'),
#   ('소름', 'Noun'),
#   ('도', 'Josa'),
#   ('잼', 'Verb'),
#   ('있', 'PreEomi'),
#   ('게', 'Eomi'),
#   ('봤', 'Verb'),
#   ('는', 'Eomi'),
#   ('뎅', 'Noun'),
#   ('잘', 'VerbPrefix'),
#   ('알려지', 'Verb'),
#   ('지', 'Eomi'),
#   ('않은', 'Verb'),
#   ('영화', 'Noun')],
#  [('영화', 'Noun'),
#   ('가', 'Josa'),
#   ('끝날', 'Verb'),
#   ('때', 'Noun'),
#   ('까지', 'Josa'),
#   ('계속', 'Noun'),
#   ('긴장하면', 'Verb'),
#   ('서', 'Eomi'),
#   ('보게', 'Verb'),
#   ('됨', 'Verb'),
#   ('전체', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('배우', 'Noun'),
#   ('들', 'Suffix'),
#   ('연기', 'Noun'),
#   ('도', 'Josa'),
#   ('정말', 'Noun'),
#   ('좋', 'Adjective'),
#   ('았', 'PreEomi'),
#   ('음', 'Eomi')],
#  [('어떤', 'Adjective'),
#   ('작품', 'Noun'),
#   ('이', 'Josa'),
#   ('만들어진', 'Verb'),
#   ('건지', 'Verb'),
#   ('대체', 'Noun'),
#   ('ㅎㅎ', 'KoreanParticle')],
#  ...]

# %%
import collections

def function(tagger):
    c = collections.Counter()
    temp =[]
    list_final = []
    for n in tagger:
        for i in n:
            if i[1] =='Adjective':
                temp.append(i)
            if i[1] =='Verb':
                temp.append(i)

    for word in temp:
        c.update(word)
    for n, c in c.most_common(3000):
        tagging = {"tag" : n, "count": c}
        list_final.append(tagging)
    return list_final[2:]

# %%
positive_word = function(tagger_p)
negative_word = function(tagger_n)

# %%
positive_word = [i['tag'] for i in positive_word if len(i['tag'])>=2]
negative_word = [i['tag'] for i in negative_word if len(i['tag'])>=2]

# %%
review = [twitter.pos(line) for line in data["reple"]]

# %%
po = []
ne = []
for pos in review:
    po_count=0
    ne_count=0
    for word in pos: 
        if word[0] in positive_word:
            po_count += 1
        if word[0] in negative_word:
            ne_count += 1
    po.append(po_count)
    ne.append(ne_count)

# %%
print(len(po), len(ne))
# Out:
# 158390
# 158390

# %%
data["positive_num"] = po
data["negative_num"] = ne

# %%
reple = data["reple"]

# %%
k= pd.DataFrame()
a=[]
for i in tagger:
    for j in i:
        a.append(j[0])
    k.append(",")

# %%
reple = [token_word(t) for t in reple]

# %%
toekn = [twitter.morphs(i) for i in reple]

# %%
from gensim.models.word2vec import Word2Vec
model = Word2Vec(toekn,min_count=12)
model.init_sims(replace=True)
wordv = model[model.wv.vocab]

# %%
model.most_similar(positive=["배우","연기"], topn=10)
# Out:
# [('연기자', 0.7864620685577393),
#  ('연기력', 0.6982911825180054),
#  ('캐릭터', 0.666132926940918),
#  ('조연', 0.6556706428527832),
#  ('여배우', 0.6379201412200928),
#  ('명연기', 0.6243919134140015),
#  ('케미', 0.6086816787719727),
#  ('아역배우', 0.5957885980606079),
#  ('액션연기', 0.5807291269302368),
#  ('열연', 0.5726385712623596)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
import numpy as np

# 문서 embedding
class TfidfEmbeddingVectorizer:
    def __init__(self, word2vec):
        self.word2vec = word2vec
        
    def transform(self, X):
        tfidf = TfidfVectorizer(analyzer = lambda x : x) 
        tfidf.fit(X)
        max_idf = max(tfidf.idf_) 
        word2weight = defaultdict(lambda : max_idf, [(w, tfidf.idf_[i]) for w, i in tfidf.vocabulary_.items()]) 
        
        array_list =[]
        for words in X:
            array_list.append(np.array(np.mean([self.word2vec[w]*word2weight[w] for w in words if w in self.word2vec] or [np.zeros(100)], axis = 0)))
        return(array_list)

vec_tf_skip_gram = TfidfEmbeddingVectorizer(wordv)

train_tf_s = vec_tf_skip_gram.transform(data["reple"][:])

# %%
from sklearn.svm import SVC
clf1 = SVC(decision_function_shape='ovo') # SVM 만들기
svc_clf_s = clf.fit(train_tf_s, label_train)  # skip-gram
svc_clf_c = clf.fit(train_tf_c, label_train)  # CBOW

# 예측값 뽑아내기
svc_pred_s = svc_clf.predict(test_tf_s) # skip-gram
svc_pred_c = svc_clf.predict(test_tf_c) # CBOW

# 정확도 확인
from sklearn import metrics
print(metrics.classification_report(label_test, svc_pred_s)) # skip-gram
